# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch as T
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm.auto import tqdm
from datetime import datetime
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy import integrate
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Classes + Helpers

# %% [markdown]
# ## Create U, S

# %%
def create_U(length_scale, Nu, Nt):
  """ Create synthetic data for u """

  # Create a kernel and a Gaussian Process Regressor
  kernel = RBF(length_scale)
  gp = GaussianProcessRegressor(kernel=kernel)

  # Create x-axis
  t = np.linspace(0, 1, Nt).reshape(-1, 1)

  # Create u samples --> U
  U = np.zeros((Nu, Nt))
  for i in range(Nu):
    random_state = np.random.randint(0, 10000)
    U[i, :] = gp.sample_y(t, random_state=random_state).flatten()

  return t, U

# %%
def create_S(t_samples, u_samples):
  # Interpolate the sampled u values
  def interp_u(t):
      return np.interp(t, t_samples, u_samples)

  # Define the ODE function ds/dt - u(t) = 0
  def myODE(t, s):
      return interp_u(t)

  # Define the time span for integration
  t_span = (t_samples[0], t_samples[-1])

  # Define the initial condition for s
  s0 = 0

  # Call solve_ivp to solve the ODE
  sol = integrate.solve_ivp(myODE, t_span, [s0], t_eval=t_samples)

  # Extract the solution
  t = sol.t
  s = sol.y[0]

  return s, t

# %% [markdown]
# ## Physics-Informed DeepONet

# %%
class FeedForward(nn.Module):
  def __init__(self, layers, activation=nn.ReLU()):
    super().__init__()
    self.layers = layers
    self.n_layers = len(layers)
    self.activation = activation

    dense_layers = [
        self.dense_layer(in_features=self.layers[i],
                         out_features=self.layers[i+1])
        for i in range(self.n_layers - 1)]

    dense_layers.append(nn.Linear(in_features=self.layers[-2],
                                  out_features=self.layers[-1]))

    self.feed_forward = nn.Sequential(*dense_layers)

  def dense_layer(self, in_features, out_features):
    dense_layer = nn.Sequential(
        nn.Linear(in_features=in_features,
                  out_features=out_features),
        self.activation,
    )
    return dense_layer

  def forward(self, x):
    return self.feed_forward(x)

# %%
class PIDeepONet(nn.Module):
  def __init__(self,
               branch_layers,
               trunk_layers,
               activation,):
    super().__init__()
    # self.bias = nn.Parameter(T.zeros(1,))
    self.branch_model = FeedForward(branch_layers, activation)
    self.trunk_model = FeedForward(trunk_layers, activation)

  def forward(self, U, t):
    branch_out = self.branch_model.forward(U)   # N x D
    trunk_out = self.trunk_model.forward(t)   # T x D
    S = T.matmul(branch_out, T.transpose(trunk_out, 0, 1))   # N x T   #+ self.bias
    return S

# %%
class ODESolver(nn.Module):
  def __init__(self,
               branch_layers,
               trunk_layers,
               activation,
               ODE_weight,
               IC_weight,
               epochs,
               lr,
               patience,
               weight_decay=0,
               dtype=T.float32,
               device='cpu',
               chkpt_path='model.pth'):
    super().__init__()

    self.device = device
    self.dtype = dtype
    self.chkpt_path = chkpt_path
    self.patience = patience
    self.w_ODE = T.tensor(ODE_weight, dtype=dtype, device=device)
    self.w_IC = T.tensor(IC_weight, dtype=dtype, device=device)
    self.epochs = epochs
    self.PIDeepONet = PIDeepONet(branch_layers, trunk_layers, activation)
    self.optimizer = T.optim.Adam(lr=lr, params=self.PIDeepONet.parameters(), weight_decay=weight_decay)

  def forward(self, U, t):
    return self.PIDeepONet.forward(U, t)

  def calculate_derivatives(self, t, U):
    Nu = U.shape[0]
    Nt = len(t)
    S_t = T.zeros(Nu, Nt)
    for i in range(Nu):
      u = U[i, :]
      s_i = self.forward(u, t).squeeze()
      grad_s_i = T.autograd.grad(
          s_i, t,
          grad_outputs=T.ones_like(s_i),
          create_graph=True,
          retain_graph=True
      )
      S_t[i, :] = grad_s_i[0].squeeze()

    return S_t

  def loss_fn(self, t_init, U_init, t, U):
    S_t = self.calculate_derivatives(t, U)
    ODE_residual = S_t - U
    IC_residual = self.forward(U_init, t_init)
    total_loss = self.w_ODE * T.mean(T.square(ODE_residual)) + \
                 self.w_IC * T.mean(F.mse_loss(IC_residual, T.tensor(0, device=self.device, dtype=self.dtype)))
    return total_loss

  def train_step(self, t_init, U_init, t, U):
    # Set 'PIDeepONet' model in training mode
    self.PIDeepONet.train()

    # Calculate loss
    loss = self.loss_fn(t_init, U_init, t, U)

    # Zero the gradients
    self.optimizer.zero_grad()

    # Back-propagate the loss
    loss.backward()

    # Implement one step of optimization
    self.optimizer.step()

    return loss.item()

  def train(self, t_init, U_init, t, U):
    losses = list()
    for epoch in tqdm(range(self.epochs)):
      flag = 0
      loss = self.train_step(t_init, U_init, t, U)

      # if self.use_scheduler:
      #   self.scheduler.step(loss)

      losses.append(loss)
      if epoch == 0:
        best_val_loss = loss
        best_epoch = -1
        self.checkpoint()
        flag = 1
        print(f"Epoch: {epoch+1}/{self.epochs} | Loss: {loss}- *Checkpoint*")
      else:
        if loss < best_val_loss:
          best_val_loss = loss
          best_epoch = epoch
          self.checkpoint()
          flag = 1
          if epoch % 1 == 0:
            print(f"Epoch: {epoch+1}/{self.epochs} | Loss: {loss} - *Checkpoint*")
        elif epoch - best_epoch > self.patience:
          if epoch % 1 == 0:
            print(f"\nEarly stopping applied at epoch {epoch}.")
          break
      if (flag == 0) and (epoch % 1 == 0):
        print(f"Epoch: {epoch+1}/{self.epochs} | Loss: {loss}")

    return losses

  def checkpoint(self):
    T.save({
      "optimizer": self.optimizer.state_dict(),
      "model": self.PIDeepONet.state_dict()
    }, self.chkpt_path)

# %% [markdown]
# # MAIN

# %%
Nu = 20
Nt = 100
length_scale = 0.4
activation = nn.Tanh()
n_hidden_layers = 3
hidden_layers_size = 50
ODE_weight = 1
IC_weight = 1
epochs = 5000
lr = 1e-3
batch_size = 20
batch_size_init = 20
dtype = T.float32
device = 'cpu'

t_train, U_train = create_U(length_scale, Nu, Nt)

scaler = MinMaxScaler()
U_train_scaled = scaler.fit_transform(U_train)

t_train = T.tensor(t_train, dtype=dtype, device=device, requires_grad=True).reshape(-1, 1)
t_train_init = T.tensor([[0.]], dtype=dtype, device=device)
U_train_scaled = T.tensor(U_train_scaled, dtype=dtype, device=device)
U_train_scaled_init = U_train_scaled[U_train_scaled[:, 0] == 0]

branch_layers = [len(t_train)] + n_hidden_layers * [hidden_layers_size]
trunk_layers = [1] + n_hidden_layers * [hidden_layers_size]

print(U_train_scaled.shape, t_train.shape)
print(U_train_scaled_init.shape)
# Out:
# torch.Size([20, 100]) torch.Size([100, 1])
# torch.Size([1, 100])

# %%
ode_solver = ODESolver(branch_layers,
                       trunk_layers,
                       activation,
                       ODE_weight,
                       IC_weight,
                       epochs,
                       lr,
                       patience=epochs+1,
                       chkpt_path='model.pth')

losses = ode_solver.train(t_train_init, U_train_scaled_init, t_train, U_train_scaled)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <ipython-input-265-7dbe74ae77fd>:52: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   self.w_IC * T.mean(F.mse_loss(IC_residual, T.tensor(0, device=self.device, dtype=self.dtype)))
# Epoch: 1/5000 | Loss: 0.31568753719329834- *Checkpoint*
# Epoch: 2/5000 | Loss: 0.155369833111763 - *Checkpoint*
# Epoch: 3/5000 | Loss: 0.06675956398248672 - *Checkpoint*
# Epoch: 4/5000 | Loss: 0.050128232687711716 - *Checkpoint*
# Epoch: 5/5000 | Loss: 0.07919018715620041
# Epoch: 6/5000 | Loss: 0.08946357667446136
# Epoch: 7/5000 | Loss: 0.07410049438476562
# Epoch: 8/5000 | Loss: 0.055118378251791
# Epoch: 9/5000 | Loss: 0.04596545547246933 - *Checkpoint*
# Epoch: 10/5000 | Loss: 0.04751885309815407
# Epoch: 11/5000 | Loss: 0.05368581786751747
# Epoch: 12/5000 | Loss: 0.05777481570839882
# Epoch: 13/5000 | Loss: 0.05651657655835152
# Epoch: 14/5000 | Loss: 0.05061580240726471
# Epoch: 15/5000 | Loss: 0.04298719763755798 - *Checkpoint*
# Epoch: 16/5000 | Loss: 0.036708783358335495 - *Checkpoint*
# Epoch: 17/5000 | Loss: 0.03365742415189743 - *Checkpoint*
# Epoch: 18/5000 | Loss: 0.03384966403245926
# Epoch: 19/5000 | Loss: 0.035613369196653366
# Epoch: 20/5000 | Loss: 0.0367731899023056
# Epoch: 21/5000 | Loss: 0.03611508011817932
# Epoch: 22/5000 | Loss: 0.03383706510066986
# Epoch: 23/5000 | Loss: 0.030924027785658836 - *Checkpoint*
# Epoch: 24/5000 | Loss: 0.02840125747025013 - *Checkpoint*
# Epoch: 25/5000 | Loss: 0.0269684549421072 - *Checkpoint*
# Epoch: 26/5000 | Loss: 0.02682121843099594 - *Checkpoint*
# Epoch: 27/5000 | Loss: 0.027546215802431107
# Epoch: 28/5000 | Loss: 0.028357386589050293
# Epoch: 29/5000 | Loss: 0.028659764677286148
# Epoch: 30/5000 | Loss: 0.028348024934530258
# Epoch: 31/5000 | Loss: 0.027593079954385757
# Epoch: 32/5000 | Loss: 0.026639653369784355 - *Checkpoint*
# Epoch: 33/5000 | Loss: 0.02586919441819191 - *Checkpoint*
# Epoch: 34/5000 | Loss: 0.025636978447437286 - *Checkpoint*
# Epoch: 35/5000 | Loss: 0.02589273452758789
# Epoch: 36/5000 | Loss: 0.026272641494870186
# Epoch: 37/5000 | Loss: 0.026484284549951553
# Epoch: 38/5000 | Loss: 0.026349572464823723
# Epoch: 39/5000 | Loss: 0.02581431344151497
# Epoch: 40/5000 | Loss: 0.02509717456996441 - *Checkpoint*
# Epoch: 41/5000 | Loss: 0.024503357708454132 - *Checkpoint*
# Epoch: 42/5000 | Loss: 0.024147696793079376 - *Checkpoint*
# Epoch: 43/5000 | Loss: 0.023998258635401726 - *Checkpoint*
# Epoch: 44/5000 | Loss: 0.023950593546032906 - *Checkpoint*
# Epoch: 45/5000 | Loss: 0.023820461705327034 - *Checkpoint*
# Epoch: 46/5000 | Loss: 0.023479653522372246 - *Checkpoint*
# Epoch: 47/5000 | Loss: 0.022974710911512375 - *Checkpoint*
# Epoch: 48/5000 | Loss: 0.022432204335927963 - *Checkpoint*
# Epoch: 49/5000 | Loss: 0.02195335365831852 - *Checkpoint*
# Epoch: 50/5000 | Loss: 0.021594621241092682 - *Checkpoint*
# Epoch: 51/5000 | Loss: 0.02132384665310383 - *Checkpoint*
# Epoch: 52/5000 | Loss: 0.02101481333374977 - *Checkpoint*
# Epoch: 53/5000 | Loss: 0.02056296542286873 - *Checkpoint*
# Epoch: 54/5000 | Loss: 0.019972769543528557 - *Checkpoint*
# Epoch: 55/5000 | Loss: 0.019323840737342834 - *Checkpoint*
# Epoch: 56/5000 | Loss: 0.018709523603320122 - *Checkpoint*
# Epoch: 57/5000 | Loss: 0.01817024126648903 - *Checkpoint*
# Epoch: 58/5000 | Loss: 0.017625506967306137 - *Checkpoint*
# Epoch: 59/5000 | Loss: 0.01693308912217617 - *Checkpoint*
# Epoch: 60/5000 | Loss: 0.016060413792729378 - *Checkpoint*
# Epoch: 61/5000 | Loss: 0.01512329000979662 - *Checkpoint*
# Epoch: 62/5000 | Loss: 0.014238432049751282 - *Checkpoint*
# Epoch: 63/5000 | Loss: 0.013388131745159626 - *Checkpoint*
# Epoch: 64/5000 | Loss: 0.012448413297533989 - *Checkpoint*
# Epoch: 65/5000 | Loss: 0.011386525817215443 - *Checkpoint*
# Epoch: 66/5000 | Loss: 0.010362397879362106 - *Checkpoint*
# Epoch: 67/5000 | Loss: 0.009465474635362625 - *Checkpoint*
# Epoch: 68/5000 | Loss: 0.008538590744137764 - *Checkpoint*
# Epoch: 69/5000 | Loss: 0.007576250936836004 - *Checkpoint*
# Epoch: 70/5000 | Loss: 0.00682424521073699 - *Checkpoint*
# Epoch: 71/5000 | Loss: 0.006257476285099983 - *Checkpoint*
# Epoch: 72/5000 | Loss: 0.005784145090728998 - *Checkpoint*
# Epoch: 73/5000 | Loss: 0.005536369048058987 - *Checkpoint*
# Epoch: 74/5000 | Loss: 0.005513392388820648 - *Checkpoint*
# Epoch: 75/5000 | Loss: 0.005654896609485149
# Epoch: 76/5000 | Loss: 0.005831437185406685
# Epoch: 77/5000 | Loss: 0.006173173431307077
# Epoch: 78/5000 | Loss: 0.006412039045244455
# Epoch: 79/5000 | Loss: 0.0065606338903307915
# Epoch: 80/5000 | Loss: 0.006602006498724222
# Epoch: 81/5000 | Loss: 0.0064888522028923035
# Epoch: 82/5000 | Loss: 0.006238708738237619
# Epoch: 83/5000 | Loss: 0.005987168289721012
# Epoch: 84/5000 | Loss: 0.005702601280063391
# Epoch: 85/5000 | Loss: 0.005449417978525162 - *Checkpoint*
# Epoch: 86/5000 | Loss: 0.005285354796797037 - *Checkpoint*
# Epoch: 87/5000 | Loss: 0.005153557285666466 - *Checkpoint*
# Epoch: 88/5000 | Loss: 0.005084306001663208 - *Checkpoint*
# Epoch: 89/5000 | Loss: 0.005078418180346489 - *Checkpoint*
# Epoch: 90/5000 | Loss: 0.00508814537897706
# Epoch: 91/5000 | Loss: 0.005116716027259827
# Epoch: 92/5000 | Loss: 0.005157959181815386
# Epoch: 93/5000 | Loss: 0.0051820045337080956
# Epoch: 94/5000 | Loss: 0.005189856979995966
# Epoch: 95/5000 | Loss: 0.005194921512156725
# Epoch: 96/5000 | Loss: 0.005167835857719183
# Epoch: 97/5000 | Loss: 0.0051354761235415936
# Epoch: 98/5000 | Loss: 0.005093247164040804
# Epoch: 99/5000 | Loss: 0.005037668161094189 - *Checkpoint*
# Epoch: 100/5000 | Loss: 0.0049825687892735004 - *Checkpoint*
# Epoch: 101/5000 | Loss: 0.004930867813527584 - *Checkpoint*
# Epoch: 102/5000 | Loss: 0.004877591505646706 - *Checkpoint*
# Epoch: 103/5000 | Loss: 0.0048403190448880196 - *Checkpoint*
# Epoch: 104/5000 | Loss: 0.004808647558093071 - *Checkpoint*
# Epoch: 105/5000 | Loss: 0.004786393605172634 - *Checkpoint*
# Epoch: 106/5000 | Loss: 0.004775740671902895 - *Checkpoint*
# Epoch: 107/5000 | Loss: 0.004767628386616707 - *Checkpoint*
# Epoch: 108/5000 | Loss: 0.004764015320688486 - *Checkpoint*
# Epoch: 109/5000 | Loss: 0.004762742668390274 - *Checkpoint*
# Epoch: 110/5000 | Loss: 0.004756201524287462 - *Checkpoint*
# Epoch: 111/5000 | Loss: 0.004750352818518877 - *Checkpoint*
# Epoch: 112/5000 | Loss: 0.004737498704344034 - *Checkpoint*
# Epoch: 113/5000 | Loss: 0.004721654113382101 - *Checkpoint*
# Epoch: 114/5000 | Loss: 0.004704332910478115 - *Checkpoint*
# Epoch: 115/5000 | Loss: 0.004684033337980509 - *Checkpoint*
# Epoch: 116/5000 | Loss: 0.004666225519031286 - *Checkpoint*
# Epoch: 117/5000 | Loss: 0.004648658912628889 - *Checkpoint*
# Epoch: 118/5000 | Loss: 0.004633558448404074 - *Checkpoint*
# Epoch: 119/5000 | Loss: 0.004621394909918308 - *Checkpoint*
# Epoch: 120/5000 | Loss: 0.004610732197761536 - *Checkpoint*
# Epoch: 121/5000 | Loss: 0.004602568224072456 - *Checkpoint*
# Epoch: 122/5000 | Loss: 0.004595480393618345 - *Checkpoint*
# Epoch: 123/5000 | Loss: 0.0045884521678090096 - *Checkpoint*
# Epoch: 124/5000 | Loss: 0.00458198506385088 - *Checkpoint*
# Epoch: 125/5000 | Loss: 0.004574214573949575 - *Checkpoint*
# Epoch: 126/5000 | Loss: 0.0045663462951779366 - *Checkpoint*
# Epoch: 127/5000 | Loss: 0.004557668697088957 - *Checkpoint*
# Epoch: 128/5000 | Loss: 0.0045483005233109 - *Checkpoint*
# Epoch: 129/5000 | Loss: 0.004539097659289837 - *Checkpoint*
# Epoch: 130/5000 | Loss: 0.004529299680143595 - *Checkpoint*
# Epoch: 131/5000 | Loss: 0.004520288668572903 - *Checkpoint*
# Epoch: 132/5000 | Loss: 0.004511423874646425 - *Checkpoint*
# Epoch: 133/5000 | Loss: 0.0045032505877316 - *Checkpoint*
# Epoch: 134/5000 | Loss: 0.004495745990425348 - *Checkpoint*
# Epoch: 135/5000 | Loss: 0.004488467704504728 - *Checkpoint*
# Epoch: 136/5000 | Loss: 0.004481850191950798 - *Checkpoint*
# Epoch: 137/5000 | Loss: 0.004475162364542484 - *Checkpoint*
# Epoch: 138/5000 | Loss: 0.004468785598874092 - *Checkpoint*
# Epoch: 139/5000 | Loss: 0.004462279379367828 - *Checkpoint*
# Epoch: 140/5000 | Loss: 0.00445568049326539 - *Checkpoint*
# Epoch: 141/5000 | Loss: 0.004449042957276106 - *Checkpoint*
# Epoch: 142/5000 | Loss: 0.004442248027771711 - *Checkpoint*
# Epoch: 143/5000 | Loss: 0.004435566253960133 - *Checkpoint*
# Epoch: 144/5000 | Loss: 0.004428851883858442 - *Checkpoint*
# Epoch: 145/5000 | Loss: 0.004422334488481283 - *Checkpoint*
# Epoch: 146/5000 | Loss: 0.004415902309119701 - *Checkpoint*
# Epoch: 147/5000 | Loss: 0.00440968107432127 - *Checkpoint*
# Epoch: 148/5000 | Loss: 0.004403584636747837 - *Checkpoint*
# Epoch: 149/5000 | Loss: 0.004397637210786343 - *Checkpoint*
# Epoch: 150/5000 | Loss: 0.004391796421259642 - *Checkpoint*
# Epoch: 151/5000 | Loss: 0.004385979846119881 - *Checkpoint*
# Epoch: 152/5000 | Loss: 0.004380253609269857 - *Checkpoint*
# Epoch: 153/5000 | Loss: 0.004374484531581402 - *Checkpoint*
# Epoch: 154/5000 | Loss: 0.004368790425360203 - *Checkpoint*
# Epoch: 155/5000 | Loss: 0.0043630744330585 - *Checkpoint*
# Epoch: 156/5000 | Loss: 0.0043574064038693905 - *Checkpoint*
# Epoch: 157/5000 | Loss: 0.004351761192083359 - *Checkpoint*
# Epoch: 158/5000 | Loss: 0.004346173722296953 - *Checkpoint*
# Epoch: 159/5000 | Loss: 0.00434064120054245 - *Checkpoint*
# Epoch: 160/5000 | Loss: 0.004335171543061733 - *Checkpoint*
# Epoch: 161/5000 | Loss: 0.004329764284193516 - *Checkpoint*
# Epoch: 162/5000 | Loss: 0.0043244012631475925 - *Checkpoint*
# Epoch: 163/5000 | Loss: 0.004319105762988329 - *Checkpoint*
# Epoch: 164/5000 | Loss: 0.00431383540853858 - *Checkpoint*
# Epoch: 165/5000 | Loss: 0.004308618605136871 - *Checkpoint*
# Epoch: 166/5000 | Loss: 0.004303422756493092 - *Checkpoint*
# Epoch: 167/5000 | Loss: 0.004298267886042595 - *Checkpoint*
# Epoch: 168/5000 | Loss: 0.0042931316420435905 - *Checkpoint*
# Epoch: 169/5000 | Loss: 0.004288038704544306 - *Checkpoint*
# Epoch: 170/5000 | Loss: 0.0042829690501093864 - *Checkpoint*
# Epoch: 171/5000 | Loss: 0.004277937579900026 - *Checkpoint*
# Epoch: 172/5000 | Loss: 0.004272936377674341 - *Checkpoint*
# Epoch: 173/5000 | Loss: 0.00426797429099679 - *Checkpoint*
# Epoch: 174/5000 | Loss: 0.004263042006641626 - *Checkpoint*
# Epoch: 175/5000 | Loss: 0.00425814650952816 - *Checkpoint*
# Epoch: 176/5000 | Loss: 0.0042532822117209435 - *Checkpoint*
# Epoch: 177/5000 | Loss: 0.004248447250574827 - *Checkpoint*
# Epoch: 178/5000 | Loss: 0.004243639763444662 - *Checkpoint*
# Epoch: 179/5000 | Loss: 0.004238861612975597 - *Checkpoint*
# Epoch: 180/5000 | Loss: 0.004234110005199909 - *Checkpoint*
# Epoch: 181/5000 | Loss: 0.004229382611811161 - *Checkpoint*
# Epoch: 182/5000 | Loss: 0.004224678501486778 - *Checkpoint*
# Epoch: 183/5000 | Loss: 0.004220000933855772 - *Checkpoint*
# Epoch: 184/5000 | Loss: 0.0042153471149504185 - *Checkpoint*
# Epoch: 185/5000 | Loss: 0.004210717044770718 - *Checkpoint*
# Epoch: 186/5000 | Loss: 0.004206113051623106 - *Checkpoint*
# Epoch: 187/5000 | Loss: 0.004201532807201147 - *Checkpoint*
# Epoch: 188/5000 | Loss: 0.004196976311504841 - *Checkpoint*
# Epoch: 189/5000 | Loss: 0.004192444495856762 - *Checkpoint*
# Epoch: 190/5000 | Loss: 0.0041879345662891865 - *Checkpoint*
# Epoch: 191/5000 | Loss: 0.004183448385447264 - *Checkpoint*
# Epoch: 192/5000 | Loss: 0.004178982228040695 - *Checkpoint*
# Epoch: 193/5000 | Loss: 0.004174537491053343 - *Checkpoint*
# Epoch: 194/5000 | Loss: 0.004170112777501345 - *Checkpoint*
# Epoch: 195/5000 | Loss: 0.004165708087384701 - *Checkpoint*
# Epoch: 196/5000 | Loss: 0.004161321558058262 - *Checkpoint*
# Epoch: 197/5000 | Loss: 0.004156955052167177 - *Checkpoint*
# Epoch: 198/5000 | Loss: 0.0041526081040501595 - *Checkpoint*
# Epoch: 199/5000 | Loss: 0.004148279316723347 - *Checkpoint*
# Epoch: 200/5000 | Loss: 0.004143969621509314 - *Checkpoint*
# Epoch: 201/5000 | Loss: 0.004139677621424198 - *Checkpoint*
# Epoch: 202/5000 | Loss: 0.004135403782129288 - *Checkpoint*
# Epoch: 203/5000 | Loss: 0.004131147172302008 - *Checkpoint*
# Epoch: 204/5000 | Loss: 0.004126906394958496 - *Checkpoint*
# Epoch: 205/5000 | Loss: 0.004122682381421328 - *Checkpoint*
# Epoch: 206/5000 | Loss: 0.0041184742003679276 - *Checkpoint*
# Epoch: 207/5000 | Loss: 0.004114280920475721 - *Checkpoint*
# Epoch: 208/5000 | Loss: 0.004110102076083422 - *Checkpoint*
# Epoch: 209/5000 | Loss: 0.0041059390641748905 - *Checkpoint*
# Epoch: 210/5000 | Loss: 0.004101790487766266 - *Checkpoint*
# Epoch: 211/5000 | Loss: 0.0040976558811962605 - *Checkpoint*
# Epoch: 212/5000 | Loss: 0.004093535710126162 - *Checkpoint*
# Epoch: 213/5000 | Loss: 0.004089429974555969 - *Checkpoint*
# Epoch: 214/5000 | Loss: 0.004085336811840534 - *Checkpoint*
# Epoch: 215/5000 | Loss: 0.004081255756318569 - *Checkpoint*
# Epoch: 216/5000 | Loss: 0.004077188204973936 - *Checkpoint*
# Epoch: 217/5000 | Loss: 0.004073131829500198 - *Checkpoint*
# Epoch: 218/5000 | Loss: 0.004069088026881218 - *Checkpoint*
# Epoch: 219/5000 | Loss: 0.004065055400133133 - *Checkpoint*
# Epoch: 220/5000 | Loss: 0.004061033949255943 - *Checkpoint*
# Epoch: 221/5000 | Loss: 0.004057022277265787 - *Checkpoint*
# Epoch: 222/5000 | Loss: 0.004053022246807814 - *Checkpoint*
# Epoch: 223/5000 | Loss: 0.004049031063914299 - *Checkpoint*
# Epoch: 224/5000 | Loss: 0.00404505105689168 - *Checkpoint*
# Epoch: 225/5000 | Loss: 0.004041078966110945 - *Checkpoint*
# Epoch: 226/5000 | Loss: 0.004037116188555956 - *Checkpoint*
# Epoch: 227/5000 | Loss: 0.004033162724226713 - *Checkpoint*
# Epoch: 228/5000 | Loss: 0.004029215779155493 - *Checkpoint*
# Epoch: 229/5000 | Loss: 0.004025277681648731 - *Checkpoint*
# Epoch: 230/5000 | Loss: 0.004021347966045141 - *Checkpoint*
# Epoch: 231/5000 | Loss: 0.004017428494989872 - *Checkpoint*
# Epoch: 232/5000 | Loss: 0.004013521131128073 - *Checkpoint*
# Epoch: 233/5000 | Loss: 0.004009638447314501 - *Checkpoint*
# Epoch: 234/5000 | Loss: 0.004005803726613522 - *Checkpoint*
# Epoch: 235/5000 | Loss: 0.004002104513347149 - *Checkpoint*
# Epoch: 236/5000 | Loss: 0.003998765721917152 - *Checkpoint*
# Epoch: 237/5000 | Loss: 0.003996498882770538 - *Checkpoint*
# Epoch: 238/5000 | Loss: 0.003997439984232187
# Epoch: 239/5000 | Loss: 0.004008536692708731
# Epoch: 240/5000 | Loss: 0.00405149394646287
# Epoch: 241/5000 | Loss: 0.0041989292949438095
# Epoch: 242/5000 | Loss: 0.004644796717911959
# Epoch: 243/5000 | Loss: 0.005848771892488003
# Epoch: 244/5000 | Loss: 0.0073536839336156845
# Epoch: 245/5000 | Loss: 0.007332636974751949
# Epoch: 246/5000 | Loss: 0.0044046975672245026
# Epoch: 247/5000 | Loss: 0.004863162059336901
# Epoch: 248/5000 | Loss: 0.006351321004331112
# Epoch: 249/5000 | Loss: 0.004310655407607555
# Epoch: 250/5000 | Loss: 0.00472245691344142
# Epoch: 251/5000 | Loss: 0.0055843135342001915
# Epoch: 252/5000 | Loss: 0.004019476938992739
# Epoch: 253/5000 | Loss: 0.004957316908985376
# Epoch: 254/5000 | Loss: 0.004758420865982771
# Epoch: 255/5000 | Loss: 0.004093134310096502
# Epoch: 256/5000 | Loss: 0.00497054448351264
# Epoch: 257/5000 | Loss: 0.004058819729834795
# Epoch: 258/5000 | Loss: 0.004466299898922443
# Epoch: 259/5000 | Loss: 0.004395152907818556
# Epoch: 260/5000 | Loss: 0.0040190923027694225
# Epoch: 261/5000 | Loss: 0.004489975515753031
# Epoch: 262/5000 | Loss: 0.003958792891353369 - *Checkpoint*
# Epoch: 263/5000 | Loss: 0.004303439054638147
# Epoch: 264/5000 | Loss: 0.004109950270503759
# Epoch: 265/5000 | Loss: 0.004066111519932747
# Epoch: 266/5000 | Loss: 0.004206992220133543
# Epoch: 267/5000 | Loss: 0.003935601096600294 - *Checkpoint*
# Epoch: 268/5000 | Loss: 0.004180665127933025
# Epoch: 269/5000 | Loss: 0.003943468444049358
# Epoch: 270/5000 | Loss: 0.004079815931618214
# Epoch: 271/5000 | Loss: 0.004005138296633959
# Epoch: 272/5000 | Loss: 0.003972508478909731
# Epoch: 273/5000 | Loss: 0.004043474327772856
# Epoch: 274/5000 | Loss: 0.0039148032665252686 - *Checkpoint*
# Epoch: 275/5000 | Loss: 0.004027869552373886
# Epoch: 276/5000 | Loss: 0.0039091557264328 - *Checkpoint*
# Epoch: 277/5000 | Loss: 0.00397844472900033
# Epoch: 278/5000 | Loss: 0.003935517743229866
# Epoch: 279/5000 | Loss: 0.003920257091522217
# Epoch: 280/5000 | Loss: 0.003952356055378914
# Epoch: 281/5000 | Loss: 0.003886368591338396 - *Checkpoint*
# Epoch: 282/5000 | Loss: 0.003941263072192669
# Epoch: 283/5000 | Loss: 0.003884140634909272 - *Checkpoint*
# Epoch: 284/5000 | Loss: 0.003908480051904917
# Epoch: 285/5000 | Loss: 0.0038954808842390776
# Epoch: 286/5000 | Loss: 0.0038754004053771496 - *Checkpoint*
# Epoch: 287/5000 | Loss: 0.0038984387647360563
# Epoch: 288/5000 | Loss: 0.0038594475481659174 - *Checkpoint*
# Epoch: 289/5000 | Loss: 0.0038817045278847218
# Epoch: 290/5000 | Loss: 0.0038603919092565775
# Epoch: 291/5000 | Loss: 0.003857632866129279 - *Checkpoint*
# Epoch: 292/5000 | Loss: 0.0038624797016382217
# Epoch: 293/5000 | Loss: 0.0038403950165957212 - *Checkpoint*
# Epoch: 294/5000 | Loss: 0.003853683592751622
# Epoch: 295/5000 | Loss: 0.003835853422060609 - *Checkpoint*
# Epoch: 296/5000 | Loss: 0.0038357931189239025 - *Checkpoint*
# Epoch: 297/5000 | Loss: 0.003834773553535342 - *Checkpoint*
# Epoch: 298/5000 | Loss: 0.0038205990567803383 - *Checkpoint*
# Epoch: 299/5000 | Loss: 0.003826859639957547
# Epoch: 300/5000 | Loss: 0.0038144125137478113 - *Checkpoint*
# Epoch: 301/5000 | Loss: 0.0038123084232211113 - *Checkpoint*
# Epoch: 302/5000 | Loss: 0.0038108956068754196 - *Checkpoint*
# Epoch: 303/5000 | Loss: 0.0038000689819455147 - *Checkpoint*
# Epoch: 304/5000 | Loss: 0.0038021234795451164
# Epoch: 305/5000 | Loss: 0.0037940030451864004 - *Checkpoint*
# Epoch: 306/5000 | Loss: 0.0037891766987740993 - *Checkpoint*
# Epoch: 307/5000 | Loss: 0.003788287052884698 - *Checkpoint*
# Epoch: 308/5000 | Loss: 0.0037794599775224924 - *Checkpoint*
# Epoch: 309/5000 | Loss: 0.0037779523991048336 - *Checkpoint*
# Epoch: 310/5000 | Loss: 0.003773296717554331 - *Checkpoint*
# Epoch: 311/5000 | Loss: 0.0037667457945644855 - *Checkpoint*
# Epoch: 312/5000 | Loss: 0.003765240078791976 - *Checkpoint*
# Epoch: 313/5000 | Loss: 0.0037589198909699917 - *Checkpoint*
# Epoch: 314/5000 | Loss: 0.003754395293071866 - *Checkpoint*
# Epoch: 315/5000 | Loss: 0.0037515955045819283 - *Checkpoint*
# Epoch: 316/5000 | Loss: 0.003745198715478182 - *Checkpoint*
# Epoch: 317/5000 | Loss: 0.0037416594568639994 - *Checkpoint*
# Epoch: 318/5000 | Loss: 0.0037376380059868097 - *Checkpoint*
# Epoch: 319/5000 | Loss: 0.0037317704409360886 - *Checkpoint*
# Epoch: 320/5000 | Loss: 0.0037283655256032944 - *Checkpoint*
# Epoch: 321/5000 | Loss: 0.003723673988133669 - *Checkpoint*
# Epoch: 322/5000 | Loss: 0.0037183035165071487 - *Checkpoint*
# Epoch: 323/5000 | Loss: 0.0037146417889744043 - *Checkpoint*
# Epoch: 324/5000 | Loss: 0.0037096859887242317 - *Checkpoint*
# Epoch: 325/5000 | Loss: 0.0037045858334749937 - *Checkpoint*
# Epoch: 326/5000 | Loss: 0.003700616303831339 - *Checkpoint*
# Epoch: 327/5000 | Loss: 0.0036955594550818205 - *Checkpoint*
# Epoch: 328/5000 | Loss: 0.003690549870952964 - *Checkpoint*
# Epoch: 329/5000 | Loss: 0.0036863000132143497 - *Checkpoint*
# Epoch: 330/5000 | Loss: 0.003681228728964925 - *Checkpoint*
# Epoch: 331/5000 | Loss: 0.0036761744413524866 - *Checkpoint*
# Epoch: 332/5000 | Loss: 0.003671688260510564 - *Checkpoint*
# Epoch: 333/5000 | Loss: 0.003666614880785346 - *Checkpoint*
# Epoch: 334/5000 | Loss: 0.0036614583805203438 - *Checkpoint*
# Epoch: 335/5000 | Loss: 0.0036567437928169966 - *Checkpoint*
# Epoch: 336/5000 | Loss: 0.0036516538821160793 - *Checkpoint*
# Epoch: 337/5000 | Loss: 0.0036463765427470207 - *Checkpoint*
# Epoch: 338/5000 | Loss: 0.0036414284259080887 - *Checkpoint*
# Epoch: 339/5000 | Loss: 0.0036362959071993828 - *Checkpoint*
# Epoch: 340/5000 | Loss: 0.0036309019196778536 - *Checkpoint*
# Epoch: 341/5000 | Loss: 0.003625711891800165 - *Checkpoint*
# Epoch: 342/5000 | Loss: 0.003620489966124296 - *Checkpoint*
# Epoch: 343/5000 | Loss: 0.003615002380684018 - *Checkpoint*
# Epoch: 344/5000 | Loss: 0.00360956066288054 - *Checkpoint*
# Epoch: 345/5000 | Loss: 0.003604188561439514 - *Checkpoint*
# Epoch: 346/5000 | Loss: 0.003598616225644946 - *Checkpoint*
# Epoch: 347/5000 | Loss: 0.003592951688915491 - *Checkpoint*
# Epoch: 348/5000 | Loss: 0.0035873549059033394 - *Checkpoint*
# Epoch: 349/5000 | Loss: 0.003581675700843334 - *Checkpoint*
# Epoch: 350/5000 | Loss: 0.003575835609808564 - *Checkpoint*
# Epoch: 351/5000 | Loss: 0.0035699792206287384 - *Checkpoint*
# Epoch: 352/5000 | Loss: 0.0035641181748360395 - *Checkpoint*
# Epoch: 353/5000 | Loss: 0.003558132331818342 - *Checkpoint*
# Epoch: 354/5000 | Loss: 0.0035520358942449093 - *Checkpoint*
# Epoch: 355/5000 | Loss: 0.003545918269082904 - *Checkpoint*
# Epoch: 356/5000 | Loss: 0.0035397482570260763 - *Checkpoint*
# Epoch: 357/5000 | Loss: 0.003533455543220043 - *Checkpoint*
# Epoch: 358/5000 | Loss: 0.0035270676016807556 - *Checkpoint*
# Epoch: 359/5000 | Loss: 0.0035206342581659555 - *Checkpoint*
# Epoch: 360/5000 | Loss: 0.0035141275729984045 - *Checkpoint*
# Epoch: 361/5000 | Loss: 0.003507506102323532 - *Checkpoint*
# Epoch: 362/5000 | Loss: 0.0035007817205041647 - *Checkpoint*
# Epoch: 363/5000 | Loss: 0.003493988886475563 - *Checkpoint*
# Epoch: 364/5000 | Loss: 0.003487112233415246 - *Checkpoint*
# Epoch: 365/5000 | Loss: 0.003480123821645975 - *Checkpoint*
# Epoch: 366/5000 | Loss: 0.0034730220213532448 - *Checkpoint*
# Epoch: 367/5000 | Loss: 0.0034658259246498346 - *Checkpoint*
# Epoch: 368/5000 | Loss: 0.003458536695688963 - *Checkpoint*
# Epoch: 369/5000 | Loss: 0.0034511361736804247 - *Checkpoint*
# Epoch: 370/5000 | Loss: 0.0034436124842613935 - *Checkpoint*
# Epoch: 371/5000 | Loss: 0.003435971215367317 - *Checkpoint*
# Epoch: 372/5000 | Loss: 0.0034282191190868616 - *Checkpoint*
# Epoch: 373/5000 | Loss: 0.0034203489776700735 - *Checkpoint*
# Epoch: 374/5000 | Loss: 0.0034123535733669996 - *Checkpoint*
# Epoch: 375/5000 | Loss: 0.0034042219631373882 - *Checkpoint*
# Epoch: 376/5000 | Loss: 0.0033959560096263885 - *Checkpoint*
# Epoch: 377/5000 | Loss: 0.0033875564113259315 - *Checkpoint*
# Epoch: 378/5000 | Loss: 0.0033790196757763624 - *Checkpoint*
# Epoch: 379/5000 | Loss: 0.0033703402150422335 - *Checkpoint*
# Epoch: 380/5000 | Loss: 0.003361509880051017 - *Checkpoint*
# Epoch: 381/5000 | Loss: 0.0033525240141898394 - *Checkpoint*
# Epoch: 382/5000 | Loss: 0.003343378659337759 - *Checkpoint*
# Epoch: 383/5000 | Loss: 0.0033340740483254194 - *Checkpoint*
# Epoch: 384/5000 | Loss: 0.0033246034290641546 - *Checkpoint*
# Epoch: 385/5000 | Loss: 0.0033149621449410915 - *Checkpoint*
# Epoch: 386/5000 | Loss: 0.003305144840851426 - *Checkpoint*
# Epoch: 387/5000 | Loss: 0.003295144299045205 - *Checkpoint*
# Epoch: 388/5000 | Loss: 0.0032849558629095554 - *Checkpoint*
# Epoch: 389/5000 | Loss: 0.003274574177339673 - *Checkpoint*
# Epoch: 390/5000 | Loss: 0.0032639927230775356 - *Checkpoint*
# Epoch: 391/5000 | Loss: 0.0032532073091715574 - *Checkpoint*
# Epoch: 392/5000 | Loss: 0.0032422116491943598 - *Checkpoint*
# Epoch: 393/5000 | Loss: 0.003230998758226633 - *Checkpoint*
# Epoch: 394/5000 | Loss: 0.003219563513994217 - *Checkpoint*
# Epoch: 395/5000 | Loss: 0.0032078977674245834 - *Checkpoint*
# Epoch: 396/5000 | Loss: 0.0031959949992597103 - *Checkpoint*
# Epoch: 397/5000 | Loss: 0.0031838484574109316 - *Checkpoint*
# Epoch: 398/5000 | Loss: 0.0031714506912976503 - *Checkpoint*
# Epoch: 399/5000 | Loss: 0.0031587935518473387 - *Checkpoint*
# Epoch: 400/5000 | Loss: 0.0031458712182939053 - *Checkpoint*
# Epoch: 401/5000 | Loss: 0.003132674377411604 - *Checkpoint*
# Epoch: 402/5000 | Loss: 0.0031191979069262743 - *Checkpoint*
# Epoch: 403/5000 | Loss: 0.003105438081547618 - *Checkpoint*
# Epoch: 404/5000 | Loss: 0.0030913965310901403 - *Checkpoint*
# Epoch: 405/5000 | Loss: 0.0030770909506827593 - *Checkpoint*
# Epoch: 406/5000 | Loss: 0.0030625828076153994 - *Checkpoint*
# Epoch: 407/5000 | Loss: 0.0030480511486530304 - *Checkpoint*
# Epoch: 408/5000 | Loss: 0.003034008899703622 - *Checkpoint*
# Epoch: 409/5000 | Loss: 0.003021962009370327 - *Checkpoint*
# Epoch: 410/5000 | Loss: 0.0030163542833179235 - *Checkpoint*
# Epoch: 411/5000 | Loss: 0.0030311851296573877
# Epoch: 412/5000 | Loss: 0.0031087948009371758
# Epoch: 413/5000 | Loss: 0.0033923075534403324
# Epoch: 414/5000 | Loss: 0.004265479743480682
# Epoch: 415/5000 | Loss: 0.006864717695862055
# Epoch: 416/5000 | Loss: 0.01084689050912857
# Epoch: 417/5000 | Loss: 0.01306297816336155
# Epoch: 418/5000 | Loss: 0.004545650444924831
# Epoch: 419/5000 | Loss: 0.005412396974861622
# Epoch: 420/5000 | Loss: 0.008777759969234467
# Epoch: 421/5000 | Loss: 0.003093337407335639
# Epoch: 422/5000 | Loss: 0.007179717533290386
# Epoch: 423/5000 | Loss: 0.005033393856137991
# Epoch: 424/5000 | Loss: 0.004448298830538988
# Epoch: 425/5000 | Loss: 0.0055290996097028255
# Epoch: 426/5000 | Loss: 0.0032428011763840914
# Epoch: 427/5000 | Loss: 0.005177607294172049
# Epoch: 428/5000 | Loss: 0.0029328097589313984 - *Checkpoint*
# Epoch: 429/5000 | Loss: 0.004941779188811779
# Epoch: 430/5000 | Loss: 0.002844042843207717 - *Checkpoint*
# Epoch: 431/5000 | Loss: 0.004356340039521456
# Epoch: 432/5000 | Loss: 0.0028319372795522213 - *Checkpoint*
# Epoch: 433/5000 | Loss: 0.004041304811835289
# Epoch: 434/5000 | Loss: 0.0027971381787210703 - *Checkpoint*
# Epoch: 435/5000 | Loss: 0.0036998065188527107
# Epoch: 436/5000 | Loss: 0.002734993351623416 - *Checkpoint*
# Epoch: 437/5000 | Loss: 0.003515907097607851
# Epoch: 438/5000 | Loss: 0.0026983851566910744 - *Checkpoint*
# Epoch: 439/5000 | Loss: 0.0033084426540881395
# Epoch: 440/5000 | Loss: 0.002671108115464449 - *Checkpoint*
# Epoch: 441/5000 | Loss: 0.0031645421404391527
# Epoch: 442/5000 | Loss: 0.0026267836801707745 - *Checkpoint*
# Epoch: 443/5000 | Loss: 0.003002486191689968
# Epoch: 444/5000 | Loss: 0.002593103563413024 - *Checkpoint*
# Epoch: 445/5000 | Loss: 0.002874775556847453
# Epoch: 446/5000 | Loss: 0.00255014980211854 - *Checkpoint*
# Epoch: 447/5000 | Loss: 0.0027503955643624067
# Epoch: 448/5000 | Loss: 0.0025173777248710394 - *Checkpoint*
# Epoch: 449/5000 | Loss: 0.002648497000336647
# Epoch: 450/5000 | Loss: 0.0024703191593289375 - *Checkpoint*
# Epoch: 451/5000 | Loss: 0.0025480289477854967
# Epoch: 452/5000 | Loss: 0.002419139025732875 - *Checkpoint*
# Epoch: 453/5000 | Loss: 0.0024614224676042795
# Epoch: 454/5000 | Loss: 0.0023599627893418074 - *Checkpoint*
# Epoch: 455/5000 | Loss: 0.0023757959716022015
# Epoch: 456/5000 | Loss: 0.0023034631740301847 - *Checkpoint*
# Epoch: 457/5000 | Loss: 0.002301248721778393 - *Checkpoint*
# Epoch: 458/5000 | Loss: 0.002241249429062009 - *Checkpoint*
# Epoch: 459/5000 | Loss: 0.002225802978500724 - *Checkpoint*
# Epoch: 460/5000 | Loss: 0.002178590279072523 - *Checkpoint*
# Epoch: 461/5000 | Loss: 0.0021546874195337296 - *Checkpoint*
# Epoch: 462/5000 | Loss: 0.0021092903334647417 - *Checkpoint*
# Epoch: 463/5000 | Loss: 0.0020848989952355623 - *Checkpoint*
# Epoch: 464/5000 | Loss: 0.002041579456999898 - *Checkpoint*
# Epoch: 465/5000 | Loss: 0.002017706399783492 - *Checkpoint*
# Epoch: 466/5000 | Loss: 0.0019721118733286858 - *Checkpoint*
# Epoch: 467/5000 | Loss: 0.0019508914556354284 - *Checkpoint*
# Epoch: 468/5000 | Loss: 0.0019035020377486944 - *Checkpoint*
# Epoch: 469/5000 | Loss: 0.001884416094981134 - *Checkpoint*
# Epoch: 470/5000 | Loss: 0.0018346592551097274 - *Checkpoint*
# Epoch: 471/5000 | Loss: 0.0018177685560658574 - *Checkpoint*
# Epoch: 472/5000 | Loss: 0.001768102403730154 - *Checkpoint*
# Epoch: 473/5000 | Loss: 0.0017529466422274709 - *Checkpoint*
# Epoch: 474/5000 | Loss: 0.0017035037744790316 - *Checkpoint*
# Epoch: 475/5000 | Loss: 0.0016880942275747657 - *Checkpoint*
# Epoch: 476/5000 | Loss: 0.001641548820771277 - *Checkpoint*
# Epoch: 477/5000 | Loss: 0.0016246578888967633 - *Checkpoint*
# Epoch: 478/5000 | Loss: 0.0015819326508790255 - *Checkpoint*
# Epoch: 479/5000 | Loss: 0.0015621186466887593 - *Checkpoint*
# Epoch: 480/5000 | Loss: 0.00152598787099123 - *Checkpoint*
# Epoch: 481/5000 | Loss: 0.0015022683655843139 - *Checkpoint*
# Epoch: 482/5000 | Loss: 0.0014729124959558249 - *Checkpoint*
# Epoch: 483/5000 | Loss: 0.0014455856289714575 - *Checkpoint*
# Epoch: 484/5000 | Loss: 0.0014224592596292496 - *Checkpoint*
# Epoch: 485/5000 | Loss: 0.001392942969687283 - *Checkpoint*
# Epoch: 486/5000 | Loss: 0.001373810926452279 - *Checkpoint*
# Epoch: 487/5000 | Loss: 0.001345189055427909 - *Checkpoint*
# Epoch: 488/5000 | Loss: 0.0013273432850837708 - *Checkpoint*
# Epoch: 489/5000 | Loss: 0.001302344840951264 - *Checkpoint*
# Epoch: 490/5000 | Loss: 0.001283354009501636 - *Checkpoint*
# Epoch: 491/5000 | Loss: 0.0012633170699700713 - *Checkpoint*
# Epoch: 492/5000 | Loss: 0.0012429506750777364 - *Checkpoint*
# Epoch: 493/5000 | Loss: 0.0012269816361367702 - *Checkpoint*
# Epoch: 494/5000 | Loss: 0.0012068880023434758 - *Checkpoint*
# Epoch: 495/5000 | Loss: 0.0011925551807507873 - *Checkpoint*
# Epoch: 496/5000 | Loss: 0.0011752989375963807 - *Checkpoint*
# Epoch: 497/5000 | Loss: 0.0011603543534874916 - *Checkpoint*
# Epoch: 498/5000 | Loss: 0.001146674039773643 - *Checkpoint*
# Epoch: 499/5000 | Loss: 0.001131444820202887 - *Checkpoint*
# Epoch: 500/5000 | Loss: 0.001119736349210143 - *Checkpoint*
# Epoch: 501/5000 | Loss: 0.0011061843251809478 - *Checkpoint*
# Epoch: 502/5000 | Loss: 0.0010943913366645575 - *Checkpoint*
# Epoch: 503/5000 | Loss: 0.0010835295543074608 - *Checkpoint*
# Epoch: 504/5000 | Loss: 0.001071682432666421 - *Checkpoint*
# Epoch: 505/5000 | Loss: 0.0010621089022606611 - *Checkpoint*
# Epoch: 506/5000 | Loss: 0.0010518338531255722 - *Checkpoint*
# Epoch: 507/5000 | Loss: 0.0010420848848298192 - *Checkpoint*
# Epoch: 508/5000 | Loss: 0.0010336582781746984 - *Checkpoint*
# Epoch: 509/5000 | Loss: 0.0010244341101497412 - *Checkpoint*
# Epoch: 510/5000 | Loss: 0.0010163127444684505 - *Checkpoint*
# Epoch: 511/5000 | Loss: 0.0010086748516187072 - *Checkpoint*
# Epoch: 512/5000 | Loss: 0.0010006139054894447 - *Checkpoint*
# Epoch: 513/5000 | Loss: 0.000993596506305039 - *Checkpoint*
# Epoch: 514/5000 | Loss: 0.000986692146398127 - *Checkpoint*
# Epoch: 515/5000 | Loss: 0.000979644013568759 - *Checkpoint*
# Epoch: 516/5000 | Loss: 0.0009734179475344718 - *Checkpoint*
# Epoch: 517/5000 | Loss: 0.0009671955485828221 - *Checkpoint*
# Epoch: 518/5000 | Loss: 0.0009609221015125513 - *Checkpoint*
# Epoch: 519/5000 | Loss: 0.0009552572155371308 - *Checkpoint*
# Epoch: 520/5000 | Loss: 0.0009496240527369082 - *Checkpoint*
# Epoch: 521/5000 | Loss: 0.0009439244167879224 - *Checkpoint*
# Epoch: 522/5000 | Loss: 0.0009386625606566668 - *Checkpoint*
# Epoch: 523/5000 | Loss: 0.0009335125796496868 - *Checkpoint*
# Epoch: 524/5000 | Loss: 0.0009282578248530626 - *Checkpoint*
# Epoch: 525/5000 | Loss: 0.0009232726879417896 - *Checkpoint*
# Epoch: 526/5000 | Loss: 0.000918478355742991 - *Checkpoint*
# Epoch: 527/5000 | Loss: 0.0009136017761193216 - *Checkpoint*
# Epoch: 528/5000 | Loss: 0.0009088261285796762 - *Checkpoint*
# Epoch: 529/5000 | Loss: 0.0009042682941071689 - *Checkpoint*
# Epoch: 530/5000 | Loss: 0.0008997244876809418 - *Checkpoint*
# Epoch: 531/5000 | Loss: 0.0008951670024544001 - *Checkpoint*
# Epoch: 532/5000 | Loss: 0.0008907511946745217 - *Checkpoint*
# Epoch: 533/5000 | Loss: 0.0008864574483595788 - *Checkpoint*
# Epoch: 534/5000 | Loss: 0.0008821653318591416 - *Checkpoint*
# Epoch: 535/5000 | Loss: 0.0008778988267295063 - *Checkpoint*
# Epoch: 536/5000 | Loss: 0.0008737510070204735 - *Checkpoint*
# Epoch: 537/5000 | Loss: 0.0008696960867382586 - *Checkpoint*
# Epoch: 538/5000 | Loss: 0.0008656593854539096 - *Checkpoint*
# Epoch: 539/5000 | Loss: 0.0008616558625362813 - *Checkpoint*
# Epoch: 540/5000 | Loss: 0.0008577406406402588 - *Checkpoint*
# Epoch: 541/5000 | Loss: 0.0008539142436347902 - *Checkpoint*
# Epoch: 542/5000 | Loss: 0.0008501350530423224 - *Checkpoint*
# Epoch: 543/5000 | Loss: 0.0008463863632641733 - *Checkpoint*
# Epoch: 544/5000 | Loss: 0.0008426951826550066 - *Checkpoint*
# Epoch: 545/5000 | Loss: 0.0008390824659727514 - *Checkpoint*
# Epoch: 546/5000 | Loss: 0.0008355402387678623 - *Checkpoint*
# Epoch: 547/5000 | Loss: 0.000832046614959836 - *Checkpoint*
# Epoch: 548/5000 | Loss: 0.0008285946678370237 - *Checkpoint*
# Epoch: 549/5000 | Loss: 0.0008251942344941199 - *Checkpoint*
# Epoch: 550/5000 | Loss: 0.0008218565490096807 - *Checkpoint*
# Epoch: 551/5000 | Loss: 0.0008185834158211946 - *Checkpoint*
# Epoch: 552/5000 | Loss: 0.0008153688395395875 - *Checkpoint*
# Epoch: 553/5000 | Loss: 0.0008122051367536187 - *Checkpoint*
# Epoch: 554/5000 | Loss: 0.0008090885239653289 - *Checkpoint*
# Epoch: 555/5000 | Loss: 0.00080601975787431 - *Checkpoint*
# Epoch: 556/5000 | Loss: 0.0008030027966015041 - *Checkpoint*
# Epoch: 557/5000 | Loss: 0.0008000393281690776 - *Checkpoint*
# Epoch: 558/5000 | Loss: 0.0007971291779540479 - *Checkpoint*
# Epoch: 559/5000 | Loss: 0.0007942723459564149 - *Checkpoint*
# Epoch: 560/5000 | Loss: 0.0007914663874544203 - *Checkpoint*
# Epoch: 561/5000 | Loss: 0.0007887114188633859 - *Checkpoint*
# Epoch: 562/5000 | Loss: 0.0007860060431994498 - *Checkpoint*
# Epoch: 563/5000 | Loss: 0.0007833500858396292 - *Checkpoint*
# Epoch: 564/5000 | Loss: 0.0007807446527294815 - *Checkpoint*
# Epoch: 565/5000 | Loss: 0.0007781937019899487 - *Checkpoint*
# Epoch: 566/5000 | Loss: 0.0007757010753266513 - *Checkpoint*
# Epoch: 567/5000 | Loss: 0.0007732832455076277 - *Checkpoint*
# Epoch: 568/5000 | Loss: 0.000770970422308892 - *Checkpoint*
# Epoch: 569/5000 | Loss: 0.0007688410114496946 - *Checkpoint*
# Epoch: 570/5000 | Loss: 0.0007670811610296369 - *Checkpoint*
# Epoch: 571/5000 | Loss: 0.0007661664276383817 - *Checkpoint*
# Epoch: 572/5000 | Loss: 0.0007673630025237799
# Epoch: 573/5000 | Loss: 0.0007740381406620145
# Epoch: 574/5000 | Loss: 0.0007960684597492218
# Epoch: 575/5000 | Loss: 0.0008601832087151706
# Epoch: 576/5000 | Loss: 0.001051547471433878
# Epoch: 577/5000 | Loss: 0.0015690563013777137
# Epoch: 578/5000 | Loss: 0.0030062550213187933
# Epoch: 579/5000 | Loss: 0.005303659476339817
# Epoch: 580/5000 | Loss: 0.007899686694145203
# Epoch: 581/5000 | Loss: 0.003596892347559333
# Epoch: 582/5000 | Loss: 0.001231588888913393
# Epoch: 583/5000 | Loss: 0.003864595666527748
# Epoch: 584/5000 | Loss: 0.0021719702053815126
# Epoch: 585/5000 | Loss: 0.0010719927959144115
# Epoch: 586/5000 | Loss: 0.0028347040060907602
# Epoch: 587/5000 | Loss: 0.0014473441988229752
# Epoch: 588/5000 | Loss: 0.001255013863556087
# Epoch: 589/5000 | Loss: 0.002150572370737791
# Epoch: 590/5000 | Loss: 0.0009009820059873164
# Epoch: 591/5000 | Loss: 0.00154105166438967
# Epoch: 592/5000 | Loss: 0.0014684090856462717
# Epoch: 593/5000 | Loss: 0.0010301589500159025
# Epoch: 594/5000 | Loss: 0.0016319631831720471
# Epoch: 595/5000 | Loss: 0.000896681216545403
# Epoch: 596/5000 | Loss: 0.0012815603986382484
# Epoch: 597/5000 | Loss: 0.0011509702308103442
# Epoch: 598/5000 | Loss: 0.0009338503004983068
# Epoch: 599/5000 | Loss: 0.0012524074409157038
# Epoch: 600/5000 | Loss: 0.0008503799908794463
# Epoch: 601/5000 | Loss: 0.0010977794881910086
# Epoch: 602/5000 | Loss: 0.0009573498391546309
# Epoch: 603/5000 | Loss: 0.0009475527331233025
# Epoch: 604/5000 | Loss: 0.0010338671272620559
# Epoch: 605/5000 | Loss: 0.0008452539914287627
# Epoch: 606/5000 | Loss: 0.0010020592017099261
# Epoch: 607/5000 | Loss: 0.0008289580582641065
# Epoch: 608/5000 | Loss: 0.0009344198042526841
# Epoch: 609/5000 | Loss: 0.0008924345602281392
# Epoch: 610/5000 | Loss: 0.0008428431465290487
# Epoch: 611/5000 | Loss: 0.0009136334410868585
# Epoch: 612/5000 | Loss: 0.0008003105176612735
# Epoch: 613/5000 | Loss: 0.0008765746606513858
# Epoch: 614/5000 | Loss: 0.0008261725888587534
# Epoch: 615/5000 | Loss: 0.0008252213010564446
# Epoch: 616/5000 | Loss: 0.0008473037160001695
# Epoch: 617/5000 | Loss: 0.0007859814795665443
# Epoch: 618/5000 | Loss: 0.0008350812131538987
# Epoch: 619/5000 | Loss: 0.0007936441106721759
# Epoch: 620/5000 | Loss: 0.0007991596939973533
# Epoch: 621/5000 | Loss: 0.000811978243291378
# Epoch: 622/5000 | Loss: 0.000771464197896421
# Epoch: 623/5000 | Loss: 0.0007995422929525375
# Epoch: 624/5000 | Loss: 0.000777105160523206
# Epoch: 625/5000 | Loss: 0.0007751529919914901
# Epoch: 626/5000 | Loss: 0.000787233526352793
# Epoch: 627/5000 | Loss: 0.0007604114944115281 - *Checkpoint*
# Epoch: 628/5000 | Loss: 0.0007757632993161678
# Epoch: 629/5000 | Loss: 0.0007652064668945968
# Epoch: 630/5000 | Loss: 0.0007570501184090972 - *Checkpoint*
# Epoch: 631/5000 | Loss: 0.0007690771599300206
# Epoch: 632/5000 | Loss: 0.0007528148125857115 - *Checkpoint*
# Epoch: 633/5000 | Loss: 0.0007548417779617012
# Epoch: 634/5000 | Loss: 0.0007566504646092653
# Epoch: 635/5000 | Loss: 0.0007450892007909715 - *Checkpoint*
# Epoch: 636/5000 | Loss: 0.0007506831316277385
# Epoch: 637/5000 | Loss: 0.0007468696567229927
# Epoch: 638/5000 | Loss: 0.0007394842687062919 - *Checkpoint*
# Epoch: 639/5000 | Loss: 0.0007439389592036605
# Epoch: 640/5000 | Loss: 0.0007379422313533723 - *Checkpoint*
# Epoch: 641/5000 | Loss: 0.0007349982624873519 - *Checkpoint*
# Epoch: 642/5000 | Loss: 0.0007376617868430912
# Epoch: 643/5000 | Loss: 0.0007314062095247209 - *Checkpoint*
# Epoch: 644/5000 | Loss: 0.0007300221477635205 - *Checkpoint*
# Epoch: 645/5000 | Loss: 0.0007307629566639662
# Epoch: 646/5000 | Loss: 0.0007259059348143637 - *Checkpoint*
# Epoch: 647/5000 | Loss: 0.0007251432398334146 - *Checkpoint*
# Epoch: 648/5000 | Loss: 0.0007249860209412873 - *Checkpoint*
# Epoch: 649/5000 | Loss: 0.0007206814480014145 - *Checkpoint*
# Epoch: 650/5000 | Loss: 0.0007200241088867188 - *Checkpoint*
# Epoch: 651/5000 | Loss: 0.000719604198820889 - *Checkpoint*
# Epoch: 652/5000 | Loss: 0.0007162060355767608 - *Checkpoint*
# Epoch: 653/5000 | Loss: 0.0007153651677072048 - *Checkpoint*
# Epoch: 654/5000 | Loss: 0.0007146928692236543 - *Checkpoint*
# Epoch: 655/5000 | Loss: 0.0007118924404494464 - *Checkpoint*
# Epoch: 656/5000 | Loss: 0.0007107369019649923 - *Checkpoint*
# Epoch: 657/5000 | Loss: 0.0007102701347321272 - *Checkpoint*
# Epoch: 658/5000 | Loss: 0.0007079535280354321 - *Checkpoint*
# Epoch: 659/5000 | Loss: 0.000706542981788516 - *Checkpoint*
# Epoch: 660/5000 | Loss: 0.0007059753988869488 - *Checkpoint*
# Epoch: 661/5000 | Loss: 0.000704217585735023 - *Checkpoint*
# Epoch: 662/5000 | Loss: 0.0007026767707429826 - *Checkpoint*
# Epoch: 663/5000 | Loss: 0.0007020389894023538 - *Checkpoint*
# Epoch: 664/5000 | Loss: 0.0007007216336205602 - *Checkpoint*
# Epoch: 665/5000 | Loss: 0.0006990795372985303 - *Checkpoint*
# Epoch: 666/5000 | Loss: 0.0006982525810599327 - *Checkpoint*
# Epoch: 667/5000 | Loss: 0.0006973104900680482 - *Checkpoint*
# Epoch: 668/5000 | Loss: 0.0006958608282729983 - *Checkpoint*
# Epoch: 669/5000 | Loss: 0.0006947548245079815 - *Checkpoint*
# Epoch: 670/5000 | Loss: 0.0006939714658074081 - *Checkpoint*
# Epoch: 671/5000 | Loss: 0.0006927978829480708 - *Checkpoint*
# Epoch: 672/5000 | Loss: 0.0006915952544659376 - *Checkpoint*
# Epoch: 673/5000 | Loss: 0.0006907557253725827 - *Checkpoint*
# Epoch: 674/5000 | Loss: 0.0006898685242049396 - *Checkpoint*
# Epoch: 675/5000 | Loss: 0.0006887281779199839 - *Checkpoint*
# Epoch: 676/5000 | Loss: 0.0006877355626784265 - *Checkpoint*
# Epoch: 677/5000 | Loss: 0.000686955580022186 - *Checkpoint*
# Epoch: 678/5000 | Loss: 0.0006860507419332862 - *Checkpoint*
# Epoch: 679/5000 | Loss: 0.0006850386271253228 - *Checkpoint*
# Epoch: 680/5000 | Loss: 0.0006841672584414482 - *Checkpoint*
# Epoch: 681/5000 | Loss: 0.0006834059022367001 - *Checkpoint*
# Epoch: 682/5000 | Loss: 0.0006825457094237208 - *Checkpoint*
# Epoch: 683/5000 | Loss: 0.0006816454697400331 - *Checkpoint*
# Epoch: 684/5000 | Loss: 0.0006808460457250476 - *Checkpoint*
# Epoch: 685/5000 | Loss: 0.0006801129202358425 - *Checkpoint*
# Epoch: 686/5000 | Loss: 0.0006793207139708102 - *Checkpoint*
# Epoch: 687/5000 | Loss: 0.0006785056903026998 - *Checkpoint*
# Epoch: 688/5000 | Loss: 0.0006777559174224734 - *Checkpoint*
# Epoch: 689/5000 | Loss: 0.0006770615582354367 - *Checkpoint*
# Epoch: 690/5000 | Loss: 0.0006763414712622762 - *Checkpoint*
# Epoch: 691/5000 | Loss: 0.0006755964132025838 - *Checkpoint*
# Epoch: 692/5000 | Loss: 0.0006748862797394395 - *Checkpoint*
# Epoch: 693/5000 | Loss: 0.0006742248660884798 - *Checkpoint*
# Epoch: 694/5000 | Loss: 0.0006735682254657149 - *Checkpoint*
# Epoch: 695/5000 | Loss: 0.0006728912703692913 - *Checkpoint*
# Epoch: 696/5000 | Loss: 0.0006722210091538727 - *Checkpoint*
# Epoch: 697/5000 | Loss: 0.0006715852068737149 - *Checkpoint*
# Epoch: 698/5000 | Loss: 0.0006709741428494453 - *Checkpoint*
# Epoch: 699/5000 | Loss: 0.0006703598774038255 - *Checkpoint*
# Epoch: 700/5000 | Loss: 0.0006697395583614707 - *Checkpoint*
# Epoch: 701/5000 | Loss: 0.0006691300659440458 - *Checkpoint*
# Epoch: 702/5000 | Loss: 0.0006685450789518654 - *Checkpoint*
# Epoch: 703/5000 | Loss: 0.0006679750513285398 - *Checkpoint*
# Epoch: 704/5000 | Loss: 0.0006674074102193117 - *Checkpoint*
# Epoch: 705/5000 | Loss: 0.0006668380228802562 - *Checkpoint*
# Epoch: 706/5000 | Loss: 0.0006662770756520331 - *Checkpoint*
# Epoch: 707/5000 | Loss: 0.000665731611661613 - *Checkpoint*
# Epoch: 708/5000 | Loss: 0.0006651993608102202 - *Checkpoint*
# Epoch: 709/5000 | Loss: 0.0006646731635555625 - *Checkpoint*
# Epoch: 710/5000 | Loss: 0.000664148828946054 - *Checkpoint*
# Epoch: 711/5000 | Loss: 0.0006636286852881312 - *Checkpoint*
# Epoch: 712/5000 | Loss: 0.0006631172145716846 - *Checkpoint*
# Epoch: 713/5000 | Loss: 0.0006626165704801679 - *Checkpoint*
# Epoch: 714/5000 | Loss: 0.0006621243082918227 - *Checkpoint*
# Epoch: 715/5000 | Loss: 0.0006616374594159424 - *Checkpoint*
# Epoch: 716/5000 | Loss: 0.0006611539865843952 - *Checkpoint*
# Epoch: 717/5000 | Loss: 0.0006606751121580601 - *Checkpoint*
# Epoch: 718/5000 | Loss: 0.00066020229132846 - *Checkpoint*
# Epoch: 719/5000 | Loss: 0.0006597363390028477 - *Checkpoint*
# Epoch: 720/5000 | Loss: 0.0006592770223505795 - *Checkpoint*
# Epoch: 721/5000 | Loss: 0.0006588240503333509 - *Checkpoint*
# Epoch: 722/5000 | Loss: 0.0006583755020983517 - *Checkpoint*
# Epoch: 723/5000 | Loss: 0.0006579303299076855 - *Checkpoint*
# Epoch: 724/5000 | Loss: 0.0006574891740456223 - *Checkpoint*
# Epoch: 725/5000 | Loss: 0.0006570529076270759 - *Checkpoint*
# Epoch: 726/5000 | Loss: 0.0006566214142367244 - *Checkpoint*
# Epoch: 727/5000 | Loss: 0.0006561951013281941 - *Checkpoint*
# Epoch: 728/5000 | Loss: 0.0006557730957865715 - *Checkpoint*
# Epoch: 729/5000 | Loss: 0.0006553554558195174 - *Checkpoint*
# Epoch: 730/5000 | Loss: 0.0006549417739734054 - *Checkpoint*
# Epoch: 731/5000 | Loss: 0.0006545310607179999 - *Checkpoint*
# Epoch: 732/5000 | Loss: 0.0006541243637911975 - *Checkpoint*
# Epoch: 733/5000 | Loss: 0.000653720460832119 - *Checkpoint*
# Epoch: 734/5000 | Loss: 0.0006533201085403562 - *Checkpoint*
# Epoch: 735/5000 | Loss: 0.0006529238307848573 - *Checkpoint*
# Epoch: 736/5000 | Loss: 0.0006525302887894213 - *Checkpoint*
# Epoch: 737/5000 | Loss: 0.0006521401810459793 - *Checkpoint*
# Epoch: 738/5000 | Loss: 0.0006517537403851748 - *Checkpoint*
# Epoch: 739/5000 | Loss: 0.0006513695698231459 - *Checkpoint*
# Epoch: 740/5000 | Loss: 0.0006509886006824672 - *Checkpoint*
# Epoch: 741/5000 | Loss: 0.0006506106583401561 - *Checkpoint*
# Epoch: 742/5000 | Loss: 0.0006502356845885515 - *Checkpoint*
# Epoch: 743/5000 | Loss: 0.0006498629227280617 - *Checkpoint*
# Epoch: 744/5000 | Loss: 0.0006494933622889221 - *Checkpoint*
# Epoch: 745/5000 | Loss: 0.0006491257809102535 - *Checkpoint*
# Epoch: 746/5000 | Loss: 0.0006487609352916479 - *Checkpoint*
# Epoch: 747/5000 | Loss: 0.0006483985926024616 - *Checkpoint*
# Epoch: 748/5000 | Loss: 0.00064803846180439 - *Checkpoint*
# Epoch: 749/5000 | Loss: 0.0006476812995970249 - *Checkpoint*
# Epoch: 750/5000 | Loss: 0.0006473264656960964 - *Checkpoint*
# Epoch: 751/5000 | Loss: 0.0006469746585935354 - *Checkpoint*
# Epoch: 752/5000 | Loss: 0.0006466260529123247 - *Checkpoint*
# Epoch: 753/5000 | Loss: 0.0006462809978984296 - *Checkpoint*
# Epoch: 754/5000 | Loss: 0.0006459418218582869 - *Checkpoint*
# Epoch: 755/5000 | Loss: 0.0006456106784753501 - *Checkpoint*
# Epoch: 756/5000 | Loss: 0.0006452915258705616 - *Checkpoint*
# Epoch: 757/5000 | Loss: 0.0006449930951930583 - *Checkpoint*
# Epoch: 758/5000 | Loss: 0.0006447314517572522 - *Checkpoint*
# Epoch: 759/5000 | Loss: 0.0006445355829782784 - *Checkpoint*
# Epoch: 760/5000 | Loss: 0.0006444657337851822 - *Checkpoint*
# Epoch: 761/5000 | Loss: 0.0006446340121328831
# Epoch: 762/5000 | Loss: 0.0006452780216932297
# Epoch: 763/5000 | Loss: 0.0006468492792919278
# Epoch: 764/5000 | Loss: 0.0006503594922833145
# Epoch: 765/5000 | Loss: 0.0006577112944796681
# Epoch: 766/5000 | Loss: 0.0006734824855811894
# Epoch: 767/5000 | Loss: 0.000705803744494915
# Epoch: 768/5000 | Loss: 0.0007764093461446464
# Epoch: 769/5000 | Loss: 0.0009168124524876475
# Epoch: 770/5000 | Loss: 0.001226085121743381
# Epoch: 771/5000 | Loss: 0.00175305490847677
# Epoch: 772/5000 | Loss: 0.0027760020457208157
# Epoch: 773/5000 | Loss: 0.003511064685881138
# Epoch: 774/5000 | Loss: 0.0038492188323289156
# Epoch: 775/5000 | Loss: 0.0019244144205003977
# Epoch: 776/5000 | Loss: 0.0007604924612678587
# Epoch: 777/5000 | Loss: 0.001588365063071251
# Epoch: 778/5000 | Loss: 0.002097819931805134
# Epoch: 779/5000 | Loss: 0.0013243986759334803
# Epoch: 780/5000 | Loss: 0.000700638978742063
# Epoch: 781/5000 | Loss: 0.0013616903452202678
# Epoch: 782/5000 | Loss: 0.0016113158781081438
# Epoch: 783/5000 | Loss: 0.0007899748161435127
# Epoch: 784/5000 | Loss: 0.0009390856139361858
# Epoch: 785/5000 | Loss: 0.0013614824274554849
# Epoch: 786/5000 | Loss: 0.0008002053946256638
# Epoch: 787/5000 | Loss: 0.0008544791489839554
# Epoch: 788/5000 | Loss: 0.0011732012499123812
# Epoch: 789/5000 | Loss: 0.0007657093228772283
# Epoch: 790/5000 | Loss: 0.0007985985139384866
# Epoch: 791/5000 | Loss: 0.0010425151558592916
# Epoch: 792/5000 | Loss: 0.0007415868458338082
# Epoch: 793/5000 | Loss: 0.0007611305918544531
# Epoch: 794/5000 | Loss: 0.0009281857637688518
# Epoch: 795/5000 | Loss: 0.0007047263788990676
# Epoch: 796/5000 | Loss: 0.0007754912949167192
# Epoch: 797/5000 | Loss: 0.0008467240841127932
# Epoch: 798/5000 | Loss: 0.0006739320233464241
# Epoch: 799/5000 | Loss: 0.0007645483128726482
# Epoch: 800/5000 | Loss: 0.0008015484781935811
# Epoch: 801/5000 | Loss: 0.0006685179541818798
# Epoch: 802/5000 | Loss: 0.0007429043180309236
# Epoch: 803/5000 | Loss: 0.0007612881017848849
# Epoch: 804/5000 | Loss: 0.0006628016126342118
# Epoch: 805/5000 | Loss: 0.0007273111841641366
# Epoch: 806/5000 | Loss: 0.000733148364815861
# Epoch: 807/5000 | Loss: 0.0006591952405869961
# Epoch: 808/5000 | Loss: 0.0007097492343746126
# Epoch: 809/5000 | Loss: 0.0007127302815206349
# Epoch: 810/5000 | Loss: 0.0006567919626832008
# Epoch: 811/5000 | Loss: 0.0006950624519959092
# Epoch: 812/5000 | Loss: 0.0006994872237555683
# Epoch: 813/5000 | Loss: 0.0006545930518768728
# Epoch: 814/5000 | Loss: 0.0006798635586164892
# Epoch: 815/5000 | Loss: 0.0006884197355248034
# Epoch: 816/5000 | Loss: 0.0006532884435728192
# Epoch: 817/5000 | Loss: 0.0006688625435344875
# Epoch: 818/5000 | Loss: 0.0006783067947253585
# Epoch: 819/5000 | Loss: 0.0006517063593491912
# Epoch: 820/5000 | Loss: 0.000658683420624584
# Epoch: 821/5000 | Loss: 0.0006711261230520904
# Epoch: 822/5000 | Loss: 0.0006516781868413091
# Epoch: 823/5000 | Loss: 0.0006501500611193478
# Epoch: 824/5000 | Loss: 0.0006623861263506114
# Epoch: 825/5000 | Loss: 0.0006514982669614255
# Epoch: 826/5000 | Loss: 0.0006449800566770136
# Epoch: 827/5000 | Loss: 0.0006543396157212555
# Epoch: 828/5000 | Loss: 0.0006501578027382493
# Epoch: 829/5000 | Loss: 0.0006418453413061798 - *Checkpoint*
# Epoch: 830/5000 | Loss: 0.0006470760563388467
# Epoch: 831/5000 | Loss: 0.0006483325269073248
# Epoch: 832/5000 | Loss: 0.0006407920154742897 - *Checkpoint*
# Epoch: 833/5000 | Loss: 0.000641001621261239
# Epoch: 834/5000 | Loss: 0.0006446247571147978
# Epoch: 835/5000 | Loss: 0.0006405747262760997 - *Checkpoint*
# Epoch: 836/5000 | Loss: 0.0006374790682457387 - *Checkpoint*
# Epoch: 837/5000 | Loss: 0.0006402523140423
# Epoch: 838/5000 | Loss: 0.00063973298529163
# Epoch: 839/5000 | Loss: 0.0006359131657518446 - *Checkpoint*
# Epoch: 840/5000 | Loss: 0.0006361948326230049
# Epoch: 841/5000 | Loss: 0.0006376765086315572
# Epoch: 842/5000 | Loss: 0.0006354180513881147 - *Checkpoint*
# Epoch: 843/5000 | Loss: 0.0006334551144391298 - *Checkpoint*
# Epoch: 844/5000 | Loss: 0.0006344837602227926
# Epoch: 845/5000 | Loss: 0.0006344754947349429
# Epoch: 846/5000 | Loss: 0.0006323934067040682 - *Checkpoint*
# Epoch: 847/5000 | Loss: 0.0006316668004728854 - *Checkpoint*
# Epoch: 848/5000 | Loss: 0.0006323521956801414
# Epoch: 849/5000 | Loss: 0.0006317026563920081
# Epoch: 850/5000 | Loss: 0.00063018110813573 - *Checkpoint*
# Epoch: 851/5000 | Loss: 0.0006298973457887769 - *Checkpoint*
# Epoch: 852/5000 | Loss: 0.0006301667308434844
# Epoch: 853/5000 | Loss: 0.0006293962942436337 - *Checkpoint*
# Epoch: 854/5000 | Loss: 0.0006283130496740341 - *Checkpoint*
# Epoch: 855/5000 | Loss: 0.000628107285592705 - *Checkpoint*
# Epoch: 856/5000 | Loss: 0.000628134177532047
# ...
# Epoch: 4689/5000 | Loss: 0.00012253817112650722
# Epoch: 4690/5000 | Loss: 0.0001225200539920479
# Epoch: 4691/5000 | Loss: 0.00011754981824196875
# Epoch: 4692/5000 | Loss: 0.00011697613081196323
# Epoch: 4693/5000 | Loss: 0.00011935611109947786
# Epoch: 4694/5000 | Loss: 0.0001163059423561208
# Epoch: 4695/5000 | Loss: 0.00011873077892232686
# Epoch: 4696/5000 | Loss: 0.00011630837252596393
# Epoch: 4697/5000 | Loss: 0.00011437127250246704
# Epoch: 4698/5000 | Loss: 0.00011537547106854618
# Epoch: 4699/5000 | Loss: 0.00011639662989182398
# Epoch: 4700/5000 | Loss: 0.00011486861330922693
# Epoch: 4701/5000 | Loss: 0.00011546368477866054
# Epoch: 4702/5000 | Loss: 0.00011395703768357635
# Epoch: 4703/5000 | Loss: 0.00011343308142386377
# Epoch: 4704/5000 | Loss: 0.00011467082367744297
# Epoch: 4705/5000 | Loss: 0.0001142641413025558
# Epoch: 4706/5000 | Loss: 0.0001138311781687662
# Epoch: 4707/5000 | Loss: 0.00011379898205632344
# Epoch: 4708/5000 | Loss: 0.00011320967314532027
# Epoch: 4709/5000 | Loss: 0.00011304564395686612
# Epoch: 4710/5000 | Loss: 0.0001138000370701775
# Epoch: 4711/5000 | Loss: 0.00011317544704070315
# Epoch: 4712/5000 | Loss: 0.00011311678099445999
# Epoch: 4713/5000 | Loss: 0.00011291301052551717
# Epoch: 4714/5000 | Loss: 0.0001127196810557507
# Epoch: 4715/5000 | Loss: 0.0001128030926338397
# Epoch: 4716/5000 | Loss: 0.00011302064376650378
# Epoch: 4717/5000 | Loss: 0.00011254791024839506
# Epoch: 4718/5000 | Loss: 0.00011257930600550026
# Epoch: 4719/5000 | Loss: 0.00011247630027355626
# Epoch: 4720/5000 | Loss: 0.00011229395749978721
# Epoch: 4721/5000 | Loss: 0.00011242334585404024
# Epoch: 4722/5000 | Loss: 0.00011246080975979567
# Epoch: 4723/5000 | Loss: 0.00011221935710636899
# Epoch: 4724/5000 | Loss: 0.00011216315760975704
# Epoch: 4725/5000 | Loss: 0.00011211264063604176
# Epoch: 4726/5000 | Loss: 0.00011198619904462248
# Epoch: 4727/5000 | Loss: 0.00011207557690795511
# Epoch: 4728/5000 | Loss: 0.00011202548193978146
# Epoch: 4729/5000 | Loss: 0.00011192756210220978
# Epoch: 4730/5000 | Loss: 0.00011187828931724653
# Epoch: 4731/5000 | Loss: 0.00011182491289218888
# Epoch: 4732/5000 | Loss: 0.0001117209903895855
# Epoch: 4733/5000 | Loss: 0.00011176846601301804
# Epoch: 4734/5000 | Loss: 0.000111718378320802
# Epoch: 4735/5000 | Loss: 0.00011165365140186623
# Epoch: 4736/5000 | Loss: 0.00011161524162162095
# Epoch: 4737/5000 | Loss: 0.00011157475819345564
# Epoch: 4738/5000 | Loss: 0.00011150351201649755
# Epoch: 4739/5000 | Loss: 0.00011150298087159172
# Epoch: 4740/5000 | Loss: 0.00011146549513796344
# Epoch: 4741/5000 | Loss: 0.00011141805589431897
# Epoch: 4742/5000 | Loss: 0.00011138484114781022
# Epoch: 4743/5000 | Loss: 0.0001113383550546132
# Epoch: 4744/5000 | Loss: 0.00011128863116027787
# Epoch: 4745/5000 | Loss: 0.0001112696627387777
# Epoch: 4746/5000 | Loss: 0.0001112385798478499
# Epoch: 4747/5000 | Loss: 0.00011119685223093256
# Epoch: 4748/5000 | Loss: 0.00011117141548311338
# Epoch: 4749/5000 | Loss: 0.00011112904030596837
# Epoch: 4750/5000 | Loss: 0.00011108424223493785
# Epoch: 4751/5000 | Loss: 0.0001110529774450697
# Epoch: 4752/5000 | Loss: 0.00011102374264737591 - *Checkpoint*
# Epoch: 4753/5000 | Loss: 0.00011098516552010551 - *Checkpoint*
# Epoch: 4754/5000 | Loss: 0.000110959357698448 - *Checkpoint*
# Epoch: 4755/5000 | Loss: 0.00011092495697084814 - *Checkpoint*
# Epoch: 4756/5000 | Loss: 0.00011088735482189804 - *Checkpoint*
# Epoch: 4757/5000 | Loss: 0.00011085272853961214 - *Checkpoint*
# Epoch: 4758/5000 | Loss: 0.0001108212090912275 - *Checkpoint*
# Epoch: 4759/5000 | Loss: 0.00011078413808718324 - *Checkpoint*
# Epoch: 4760/5000 | Loss: 0.00011075538350269198 - *Checkpoint*
# Epoch: 4761/5000 | Loss: 0.00011072388588218018 - *Checkpoint*
# Epoch: 4762/5000 | Loss: 0.00011069016181863844 - *Checkpoint*
# Epoch: 4763/5000 | Loss: 0.00011065715807490051 - *Checkpoint*
# Epoch: 4764/5000 | Loss: 0.00011062568228226155 - *Checkpoint*
# Epoch: 4765/5000 | Loss: 0.0001105904157157056 - *Checkpoint*
# Epoch: 4766/5000 | Loss: 0.00011055878712795675 - *Checkpoint*
# Epoch: 4767/5000 | Loss: 0.00011052793706767261 - *Checkpoint*
# Epoch: 4768/5000 | Loss: 0.00011049578461097553 - *Checkpoint*
# Epoch: 4769/5000 | Loss: 0.00011046433792216703 - *Checkpoint*
# Epoch: 4770/5000 | Loss: 0.00011043385893572122 - *Checkpoint*
# Epoch: 4771/5000 | Loss: 0.00011040134995710105 - *Checkpoint*
# Epoch: 4772/5000 | Loss: 0.00011036906653316692 - *Checkpoint*
# Epoch: 4773/5000 | Loss: 0.00011033770715584978 - *Checkpoint*
# Epoch: 4774/5000 | Loss: 0.00011030580208171159 - *Checkpoint*
# Epoch: 4775/5000 | Loss: 0.00011027430446119979 - *Checkpoint*
# Epoch: 4776/5000 | Loss: 0.00011024379637092352 - *Checkpoint*
# Epoch: 4777/5000 | Loss: 0.00011021272803191096 - *Checkpoint*
# Epoch: 4778/5000 | Loss: 0.00011018158693332225 - *Checkpoint*
# Epoch: 4779/5000 | Loss: 0.00011015107156708837 - *Checkpoint*
# Epoch: 4780/5000 | Loss: 0.00011011991591658443 - *Checkpoint*
# Epoch: 4781/5000 | Loss: 0.0001100888111977838 - *Checkpoint*
# Epoch: 4782/5000 | Loss: 0.0001100579829653725 - *Checkpoint*
# Epoch: 4783/5000 | Loss: 0.00011002753308275715 - *Checkpoint*
# Epoch: 4784/5000 | Loss: 0.00010999674850609154 - *Checkpoint*
# Epoch: 4785/5000 | Loss: 0.000109966415038798 - *Checkpoint*
# Epoch: 4786/5000 | Loss: 0.00010993611795129254 - *Checkpoint*
# Epoch: 4787/5000 | Loss: 0.00010990584269165993 - *Checkpoint*
# Epoch: 4788/5000 | Loss: 0.00010987543646479025 - *Checkpoint*
# Epoch: 4789/5000 | Loss: 0.00010984554683091119 - *Checkpoint*
# Epoch: 4790/5000 | Loss: 0.00010981514060404152 - *Checkpoint*
# Epoch: 4791/5000 | Loss: 0.00010978495265590027 - *Checkpoint*
# Epoch: 4792/5000 | Loss: 0.00010975499753840268 - *Checkpoint*
# Epoch: 4793/5000 | Loss: 0.0001097251515602693 - *Checkpoint*
# Epoch: 4794/5000 | Loss: 0.00010969518189085647 - *Checkpoint*
# Epoch: 4795/5000 | Loss: 0.00010966547415591776 - *Checkpoint*
# Epoch: 4796/5000 | Loss: 0.00010963561362586915 - *Checkpoint*
# Epoch: 4797/5000 | Loss: 0.00010960602230625227 - *Checkpoint*
# Epoch: 4798/5000 | Loss: 0.00010957642371067777 - *Checkpoint*
# Epoch: 4799/5000 | Loss: 0.0001095470433938317 - *Checkpoint*
# Epoch: 4800/5000 | Loss: 0.00010951763397315517 - *Checkpoint*
# Epoch: 4801/5000 | Loss: 0.00010948815906886011 - *Checkpoint*
# Epoch: 4802/5000 | Loss: 0.00010945902613457292 - *Checkpoint*
# Epoch: 4803/5000 | Loss: 0.00010942981316475198 - *Checkpoint*
# Epoch: 4804/5000 | Loss: 0.00010940068023046479 - *Checkpoint*
# Epoch: 4805/5000 | Loss: 0.0001093718092306517 - *Checkpoint*
# Epoch: 4806/5000 | Loss: 0.00010934296733466908 - *Checkpoint*
# Epoch: 4807/5000 | Loss: 0.0001093144528567791 - *Checkpoint*
# Epoch: 4808/5000 | Loss: 0.00010928622214123607 - *Checkpoint*
# Epoch: 4809/5000 | Loss: 0.00010925842798314989 - *Checkpoint*
# Epoch: 4810/5000 | Loss: 0.00010923133231699467 - *Checkpoint*
# Epoch: 4811/5000 | Loss: 0.00010920494241872802 - *Checkpoint*
# Epoch: 4812/5000 | Loss: 0.00010918021143879741 - *Checkpoint*
# Epoch: 4813/5000 | Loss: 0.00010915737220784649 - *Checkpoint*
# Epoch: 4814/5000 | Loss: 0.00010913801816059276 - *Checkpoint*
# Epoch: 4815/5000 | Loss: 0.00010912368452409282 - *Checkpoint*
# Epoch: 4816/5000 | Loss: 0.00010911785648204386 - *Checkpoint*
# Epoch: 4817/5000 | Loss: 0.00010912557627307251
# Epoch: 4818/5000 | Loss: 0.0001091554804588668
# Epoch: 4819/5000 | Loss: 0.00010922200453933328
# Epoch: 4820/5000 | Loss: 0.00010934896272374317
# Epoch: 4821/5000 | Loss: 0.00010957914491882548
# Epoch: 4822/5000 | Loss: 0.000109981803689152
# Epoch: 4823/5000 | Loss: 0.00011068496678490192
# Epoch: 4824/5000 | Loss: 0.00011189553333679214
# Epoch: 4825/5000 | Loss: 0.00011401413212297484
# Epoch: 4826/5000 | Loss: 0.00011766460374929011
# Epoch: 4827/5000 | Loss: 0.00012413710646796972
# Epoch: 4828/5000 | Loss: 0.00013528081763070077
# Epoch: 4829/5000 | Loss: 0.0001552835019538179
# Epoch: 4830/5000 | Loss: 0.00018902965530287474
# Epoch: 4831/5000 | Loss: 0.00024933318491093814
# Epoch: 4832/5000 | Loss: 0.0003431582299526781
# Epoch: 4833/5000 | Loss: 0.0005002321559004486
# Epoch: 4834/5000 | Loss: 0.0006856890395283699
# Epoch: 4835/5000 | Loss: 0.0009246054105460644
# Epoch: 4836/5000 | Loss: 0.0009873929666355252
# Epoch: 4837/5000 | Loss: 0.000964306469541043
# Epoch: 4838/5000 | Loss: 0.0007048621191643178
# Epoch: 4839/5000 | Loss: 0.0006118601304478943
# Epoch: 4840/5000 | Loss: 0.0006563793867826462
# Epoch: 4841/5000 | Loss: 0.0007445382652804255
# Epoch: 4842/5000 | Loss: 0.0005758153274655342
# Epoch: 4843/5000 | Loss: 0.0002110250643454492
# Epoch: 4844/5000 | Loss: 0.00019781033915933222
# Epoch: 4845/5000 | Loss: 0.000490460020955652
# Epoch: 4846/5000 | Loss: 0.0005475470097735524
# Epoch: 4847/5000 | Loss: 0.0003044847398996353
# Epoch: 4848/5000 | Loss: 0.00020879441581200808
# Epoch: 4849/5000 | Loss: 0.0003086762735620141
# Epoch: 4850/5000 | Loss: 0.00024424807634204626
# Epoch: 4851/5000 | Loss: 0.00014533150533679873
# Epoch: 4852/5000 | Loss: 0.00027002516435459256
# Epoch: 4853/5000 | Loss: 0.000322656036587432
# Epoch: 4854/5000 | Loss: 0.00018734094919636846
# Epoch: 4855/5000 | Loss: 0.0001820931793190539
# Epoch: 4856/5000 | Loss: 0.0002092726354021579
# Epoch: 4857/5000 | Loss: 0.00013720897550228983
# Epoch: 4858/5000 | Loss: 0.0001645660522626713
# Epoch: 4859/5000 | Loss: 0.00021486164769157767
# Epoch: 4860/5000 | Loss: 0.0001575359929120168
# Epoch: 4861/5000 | Loss: 0.0001472941366955638
# Epoch: 4862/5000 | Loss: 0.00016305925964843482
# Epoch: 4863/5000 | Loss: 0.00012114242417737842
# Epoch: 4864/5000 | Loss: 0.00013332153321243823
# Epoch: 4865/5000 | Loss: 0.00016483139188494533
# Epoch: 4866/5000 | Loss: 0.00014009492588229477
# Epoch: 4867/5000 | Loss: 0.00014480740355793387
# Epoch: 4868/5000 | Loss: 0.00015032882220111787
# Epoch: 4869/5000 | Loss: 0.0001221708080265671
# Epoch: 4870/5000 | Loss: 0.00012457290722522885
# Epoch: 4871/5000 | Loss: 0.00013056294119451195
# Epoch: 4872/5000 | Loss: 0.00011505057773320004
# Epoch: 4873/5000 | Loss: 0.00012436801625881344
# Epoch: 4874/5000 | Loss: 0.00012923272151965648
# Epoch: 4875/5000 | Loss: 0.00011987851758021861
# Epoch: 4876/5000 | Loss: 0.0001278460113098845
# Epoch: 4877/5000 | Loss: 0.0001272510562557727
# Epoch: 4878/5000 | Loss: 0.00011843862012028694
# Epoch: 4879/5000 | Loss: 0.00012173213326605037
# Epoch: 4880/5000 | Loss: 0.00011787383846240118
# Epoch: 4881/5000 | Loss: 0.0001116049534175545
# Epoch: 4882/5000 | Loss: 0.00011547206668183208
# Epoch: 4883/5000 | Loss: 0.00011342472862452269
# Epoch: 4884/5000 | Loss: 0.00011165547766722739
# Epoch: 4885/5000 | Loss: 0.0001158629238489084
# Epoch: 4886/5000 | Loss: 0.00011427535355323926
# Epoch: 4887/5000 | Loss: 0.00011369073763489723
# Epoch: 4888/5000 | Loss: 0.00011637592979241163
# Epoch: 4889/5000 | Loss: 0.00011453478509793058
# Epoch: 4890/5000 | Loss: 0.00011445699783507735
# Epoch: 4891/5000 | Loss: 0.00011607576016103849
# Epoch: 4892/5000 | Loss: 0.00011406796693336219
# Epoch: 4893/5000 | Loss: 0.00011382873344700783
# Epoch: 4894/5000 | Loss: 0.00011434918269515038
# Epoch: 4895/5000 | Loss: 0.00011247742804698646
# Epoch: 4896/5000 | Loss: 0.00011232231190660968
# Epoch: 4897/5000 | Loss: 0.000112533314677421
# Epoch: 4898/5000 | Loss: 0.00011119067494291812
# Epoch: 4899/5000 | Loss: 0.00011133466614410281
# Epoch: 4900/5000 | Loss: 0.00011141436698380858
# Epoch: 4901/5000 | Loss: 0.00011045068094972521
# Epoch: 4902/5000 | Loss: 0.00011060019460273907
# Epoch: 4903/5000 | Loss: 0.00011057090887334198
# Epoch: 4904/5000 | Loss: 0.000109906803118065
# Epoch: 4905/5000 | Loss: 0.0001101687885238789
# Epoch: 4906/5000 | Loss: 0.00011019834346370772
# Epoch: 4907/5000 | Loss: 0.00010983150423271582
# Epoch: 4908/5000 | Loss: 0.00011013659241143614
# Epoch: 4909/5000 | Loss: 0.00011022392573067918
# Epoch: 4910/5000 | Loss: 0.00011006175918737426
# Epoch: 4911/5000 | Loss: 0.00011047808220610023
# Epoch: 4912/5000 | Loss: 0.00011080045806011185
# Epoch: 4913/5000 | Loss: 0.0001111427991418168
# Epoch: 4914/5000 | Loss: 0.00011210703814867884
# Epoch: 4915/5000 | Loss: 0.00011333841393934563
# Epoch: 4916/5000 | Loss: 0.00011503843415994197
# Epoch: 4917/5000 | Loss: 0.00011804577661678195
# Epoch: 4918/5000 | Loss: 0.00012236708425916731
# Epoch: 4919/5000 | Loss: 0.0001292386878049001
# Epoch: 4920/5000 | Loss: 0.0001398029417032376
# Epoch: 4921/5000 | Loss: 0.00015699065988883376
# Epoch: 4922/5000 | Loss: 0.00018226963584311306
# Epoch: 4923/5000 | Loss: 0.00022473506396636367
# Epoch: 4924/5000 | Loss: 0.00028381490847095847
# Epoch: 4925/5000 | Loss: 0.000381785532226786
# Epoch: 4926/5000 | Loss: 0.0004963167593814433
# Epoch: 4927/5000 | Loss: 0.0006708373548462987
# Epoch: 4928/5000 | Loss: 0.0007841766346246004
# Epoch: 4929/5000 | Loss: 0.0009044270846061409
# Epoch: 4930/5000 | Loss: 0.0007761677843518555
# Epoch: 4931/5000 | Loss: 0.0005785974208265543
# Epoch: 4932/5000 | Loss: 0.00028708219178952277
# Epoch: 4933/5000 | Loss: 0.0001399196480633691
# Epoch: 4934/5000 | Loss: 0.00018184553482569754
# Epoch: 4935/5000 | Loss: 0.000310368777718395
# Epoch: 4936/5000 | Loss: 0.0003945003845728934
# Epoch: 4937/5000 | Loss: 0.0003237365453969687
# Epoch: 4938/5000 | Loss: 0.0002342638181289658
# Epoch: 4939/5000 | Loss: 0.00020195840625092387
# Epoch: 4940/5000 | Loss: 0.00023083476116880774
# Epoch: 4941/5000 | Loss: 0.0002385474945185706
# Epoch: 4942/5000 | Loss: 0.00020581018179655075
# Epoch: 4943/5000 | Loss: 0.0001986506540561095
# Epoch: 4944/5000 | Loss: 0.00020698457956314087
# Epoch: 4945/5000 | Loss: 0.00019566871924325824
# Epoch: 4946/5000 | Loss: 0.0001440976484445855
# Epoch: 4947/5000 | Loss: 0.00014636876585427672
# Epoch: 4948/5000 | Loss: 0.00018442606960888952
# Epoch: 4949/5000 | Loss: 0.0001787307410268113
# Epoch: 4950/5000 | Loss: 0.0001268316846108064
# Epoch: 4951/5000 | Loss: 0.0001247834152309224
# Epoch: 4952/5000 | Loss: 0.00014699104940518737
# Epoch: 4953/5000 | Loss: 0.00014265210484154522
# Epoch: 4954/5000 | Loss: 0.00012202338257338852
# Epoch: 4955/5000 | Loss: 0.0001349054800812155
# Epoch: 4956/5000 | Loss: 0.00013637484516948462
# Epoch: 4957/5000 | Loss: 0.00011773740698117763
# Epoch: 4958/5000 | Loss: 0.00011610580259002745
# Epoch: 4959/5000 | Loss: 0.00012936546409036964
# Epoch: 4960/5000 | Loss: 0.00012358905223663896
# Epoch: 4961/5000 | Loss: 0.00011710612307069823
# Epoch: 4962/5000 | Loss: 0.00012284917465876788
# Epoch: 4963/5000 | Loss: 0.00011878016084665433
# Epoch: 4964/5000 | Loss: 0.00011175447434652597
# Epoch: 4965/5000 | Loss: 0.000115481365355663
# Epoch: 4966/5000 | Loss: 0.00011850078590214252
# Epoch: 4967/5000 | Loss: 0.00011393600289011374
# Epoch: 4968/5000 | Loss: 0.00011534303484950215
# Epoch: 4969/5000 | Loss: 0.00011595169053180143
# Epoch: 4970/5000 | Loss: 0.0001119980588555336
# Epoch: 4971/5000 | Loss: 0.00011079706746386364
# Epoch: 4972/5000 | Loss: 0.00011307355453027412
# Epoch: 4973/5000 | Loss: 0.00011111450294265524
# Epoch: 4974/5000 | Loss: 0.00011121817806269974
# Epoch: 4975/5000 | Loss: 0.00011288564564893022
# Epoch: 4976/5000 | Loss: 0.00011172542144777253
# Epoch: 4977/5000 | Loss: 0.00010999268852174282
# Epoch: 4978/5000 | Loss: 0.00011112169886473566
# Epoch: 4979/5000 | Loss: 0.00011012089817086235
# Epoch: 4980/5000 | Loss: 0.00010894996376009658 - *Checkpoint*
# Epoch: 4981/5000 | Loss: 0.00010991115414071828
# Epoch: 4982/5000 | Loss: 0.00011028606968466192
# Epoch: 4983/5000 | Loss: 0.00010925102105829865
# Epoch: 4984/5000 | Loss: 0.00010983869287883863
# Epoch: 4985/5000 | Loss: 0.00011012220056727529
# Epoch: 4986/5000 | Loss: 0.00010914095037151128
# Epoch: 4987/5000 | Loss: 0.00010898420441662893
# Epoch: 4988/5000 | Loss: 0.00010928641131613404
# Epoch: 4989/5000 | Loss: 0.00010869328252738342 - *Checkpoint*
# Epoch: 4990/5000 | Loss: 0.00010851387196453288 - *Checkpoint*
# Epoch: 4991/5000 | Loss: 0.00010892474529100582
# Epoch: 4992/5000 | Loss: 0.0001087377531803213
# Epoch: 4993/5000 | Loss: 0.00010858750465558842
# Epoch: 4994/5000 | Loss: 0.00010880555055337027
# Epoch: 4995/5000 | Loss: 0.00010871701670112088
# Epoch: 4996/5000 | Loss: 0.00010844213829841465 - *Checkpoint*
# Epoch: 4997/5000 | Loss: 0.00010850940452655777
# Epoch: 4998/5000 | Loss: 0.00010839667811524123 - *Checkpoint*
# Epoch: 4999/5000 | Loss: 0.000108183769043535 - *Checkpoint*
# Epoch: 5000/5000 | Loss: 0.0001081675072782673 - *Checkpoint*
